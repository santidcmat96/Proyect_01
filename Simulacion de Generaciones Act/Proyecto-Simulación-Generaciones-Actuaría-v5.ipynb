# %%
# -*- coding: utf-8 -*-
from __future__ import division
import scipy.stats as st
import warnings
import itertools
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import pandas as pd
from pandas import Series
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.arima_model import ARIMA
from math import sqrt
from sqlalchemy import create_engine
import numpy as np
import os 
#from pygal import Bar,StackedBar
import seaborn as sns
import matplotlib.pyplot as plt
from fitter import Fitter 
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt
#import plotly 
#plotly.tools.set_credentials_file(username='dbhpresidente', api_key='VbaoYWxvXkrMvIx6ca9Y')
#import plotly.graph_objs as go
# %matplotlib inline
# Out:
# /home/cesar5484/anaconda2/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
##Carga de datos
df_ingresos=pd.read_csv('ingresos.csv')
df_plan_de_estudios=pd.read_csv('plan_de_estudios.csv')
df_egresados_titulados=pd.read_csv('egresados_titulos.csv')
df_activos=pd.read_csv('activos.csv')
df_indice_reprobados=pd.read_csv('indice_reprobados.csv')
df_base=pd.read_csv('base.csv')
df_tabla_prof=pd.read_csv('tabla_prof.csv')
df_tabla_final=pd.read_csv('tabla_final.csv')
df_tabla_mat=pd.read_csv('tabla_mat.csv')

# %%
##Analisis de modelo de ingresos
y=df_ingresos.copy()
y= pd.Series(df_ingresos['Total'].tolist(),index=y['Año'])
y=pd.DataFrame(y,columns=['Ingresos'])
y['new']="-08-01"
y['new1']=y.index.astype(str)
y['year']=y['new1']+y['new']
y.index=y['year']
y.plot(figsize=(15, 6))
plt.show()
y=y.drop(['new','year'],axis=1)

# %%
y=y.drop('new1',axis=1)

# %%
# prepare data
X = y.values
X = X.astype('float32')
train_size = int(len(X) * 0.50)
train, test = X[0:train_size], X[train_size:]
# walk-forward validation
history = [x for x in train]
predictions = list()
for i in range(len(test)):
    # predict
    model = ARIMA(history, order=(0,1,0))
    model_fit = model.fit(disp=0)
    yhat = model_fit.forecast()[0]
    predictions.append(yhat)
    # observation
    obs = test[i]
    history.append(obs)
    print('>Predicted=%.3f, Expected=%3.f' % (yhat, obs))
# report performance
mse = mean_squared_error(test, predictions)
rmse = sqrt(mse)
print('RMSE: %.3f' % rmse)
# Out:
# >Predicted=336.857, Expected=443
# >Predicted=459.125, Expected=383
# >Predicted=390.667, Expected=424
# >Predicted=435.000, Expected=428
# >Predicted=438.364, Expected=432
# >Predicted=441.833, Expected=480
# >Predicted=492.769, Expected=517
# >Predicted=531.500, Expected=507
# RMSE: 51.120

# %%
residuals = [test[i]-predictions[i] for i in range(len(test))]
residuals = pd.DataFrame(residuals)
print(residuals.describe())
# Out:
#                 0
# count    8.000000
# mean    10.985624
# std     53.372722
# min    -76.125000
# 25%    -11.375000
# 50%      8.933566
# 75%     34.541667
# max    106.142857

# %%
m_ingresos=float(residuals.mean())
s_ingresos=float(residuals.std())
bias = np.random.normal(m_ingresos,s_ingresos)
yhat = bias+float(model_fit.forecast()[0])
print('Predicted: %.0f' % yhat)
# Out:
# Predicted: 561

# %%
y=df_ingresos.copy()
y= pd.Series(df_ingresos['Total'].tolist(),index=y['Año'])
y=pd.DataFrame(y,columns=['Ingresos'])
y['new']="-08-01"
y['new1']=y.index.astype(str)
y['year']=y['new1']+y['new']
y.index=y['year']
y=y.drop(['new','year'],axis=1)
X=y['new1'].copy().astype(float).tolist()
Y=y['Ingresos'].copy().astype(float).tolist()
# Calculamos los coeficientes del ajuste (a X + b)
a_ingresos, b_ingresos = np.polyfit(X, Y, 1)
# Calculamos el coeficiente de correlación
r = np.corrcoef(X, Y)
# Dibujamos los datos para poder visualizarlos y ver si sería lógico 
# considerar el ajuste usando un modelo lineal
plt.plot(X, Y, 'o')
plt.xlim(np.min(X) -1, np.max(X) +1)
plt.ylim(np.min(Y) -1, np.max(Y) +1)
y['aux']=y['new1'].astype(float)*a_ingresos+b_ingresos
plt.plot(X, y['aux'].tolist(),linestyle='--',linewidth=1.0,color="red")

# %%
int(2018*a_ingresos+b_ingresos+np.random.normal(m_ingresos,s_ingresos))
# Out:
# 482

# %%
##Analisis de modelo de egresos
w=df_egresados_titulados.copy()
w['new']="-05-31"
w.index=w['Gen.']
w['new1']=w.index.astype(str)
w['year']=w['new1']+w['new']
w.index=w['year']
w=w.drop(['new','year'],axis=1)
w=w.drop('Gen.',axis=1)
w=w.drop('1969-05-31',axis=0)
w.plot(figsize=(15, 6))
w
plt.plot(w['new1'],w.EGRESADOS,'-')

# %%
# prepare data
m=w.drop(['TITULADOS','new1'],axis=1)
X = m.values
X = X.astype('float32')
train_size = int(len(X) * 0.50)
train, test = X[0:train_size], X[train_size:]
# walk-forward validation
history = [x for x in train]
predictions = list()
for i in range(len(test)):
    # predict
    model = ARIMA(history, order=(0,1,0))
    model_fit = model.fit(disp=0)
    yhat = model_fit.forecast()[0]
    predictions.append(yhat)
    # observation
    obs = test[i]
    history.append(obs)
    print('>Predicted=%.3f, Expected=%3.f' % (yhat, obs))
# report performance
mse = mean_squared_error(test, predictions)
rmse = sqrt(mse)
print('RMSE: %.3f' % rmse)
# Out:
# >Predicted=56.368, Expected= 53
# >Predicted=55.200, Expected= 58
# >Predicted=60.333, Expected= 91
# >Predicted=94.727, Expected= 76
# >Predicted=78.913, Expected= 59
# >Predicted=61.083, Expected= 63
# >Predicted=65.160, Expected= 75
# >Predicted=77.538, Expected= 88
# >Predicted=90.926, Expected= 80
# >Predicted=82.536, Expected= 84
# >Predicted=86.586, Expected= 82
# >Predicted=84.433, Expected= 91
# >Predicted=93.645, Expected=110
# >Predicted=113.156, Expected= 86
# >Predicted=88.333, Expected= 95
# >Predicted=97.529, Expected= 97
# >Predicted=99.514, Expected= 98
# >Predicted=100.472, Expected=107
# >Predicted=109.649, Expected= 64
# >Predicted=65.447, Expected= 37
# RMSE: 17.450

# %%
residuals = [test[i]-predictions[i] for i in range(len(test))]
residuals = pd.DataFrame(residuals)
print(residuals.describe())
# Out:
#                0
# count  20.000000
# mean   -3.377586
# std    17.564843
# min   -45.648649
# 25%   -12.876263
# 50%     0.467437
# 75%     6.591667
# max    30.666667

# %%
m_egresos=float(residuals.mean())
s_egresos=float(residuals.std())
bias = np.random.normal(m_egresos,s_egresos)
yhat = bias+float(model_fit.forecast()[0])
print('Predicted: %.0f' % yhat)
# Out:
# Predicted: 74

# %%
df_egresados_titulados.index=df_egresados_titulados['Gen.']
w=df_egresados_titulados.copy()
w=w.drop([2013,2014],axis=0)
X=w['Gen.'].copy().astype(float).tolist()
Y=w['EGRESADOS'].copy().astype(float).tolist()
# Calculamos los coeficientes del ajuste (a X + b)
a_egresos, b_egresos = np.polyfit(X, Y, 1)
# Calculamos el coeficiente de correlación
r = np.corrcoef(X, Y)
# Dibujamos los datos para poder visualizarlos y ver si sería lógico 
# considerar el ajuste usando un modelo lineal
plt.plot(X, Y, 'o')
plt.xlim(np.min(X) -1, np.max(X) +1)
plt.ylim(np.min(Y) -1, np.max(Y) +1)
w['aux']=w['Gen.'].astype(float)*a_egresos+b_egresos
plt.plot(X, w['aux'].tolist(),linestyle='--', linewidth=1.0,color='red')

# %%
int(2015*a_egresos+b_egresos+np.random.normal(m_egresos,s_egresos))
# Out:
# 118

# %%
def sim_ingreso(n,gen):
    z=[]
    for i in range(0,n):
        z.append(int(gen*a_ingresos+b_ingresos+np.random.normal(m_ingresos,s_ingresos)))
    return z
def sim_egreso(n,gen):
    z=[]
    for i in range(0,n):
        z.append(int(gen*a_egresos+b_egresos+np.random.normal(m_egresos,s_egresos)))
    return z

# %%
##Los Ingresos
z1=[]
for i in y['new1']:
    z1.append(int(pd.DataFrame(sim_ingreso(100000,int(i))).mean()))
y['new2']=z1
z2=[]
for i in w['aux']:
    z2.append(int(pd.DataFrame(sim_egreso(100000,int(i))).mean()))
w['new2']=z2

# %%
##Los egresos esperados
int(pd.DataFrame(sim_egreso(100000,2015)).mean())
# Out:
# 108

# %%
y['error']=(y.Ingresos-y.new2)/y.Ingresos
print y['error'].mean()
# Out:
# -0.0895295070819

# %%
w['error']=(w.EGRESADOS-w.aux)/w.EGRESADOS
print w['error'].mean()
# Out:
# -0.242343759029

# %%
df_activos
# Out:
#                             NOMBRE_PROFESOR  ID_PROFESOR
# 0                CHAVEZ GARCIA MIGUEL ANGEL          165
# 1           CAÑADA BAPTISTA FERNANDO DANIEL          166
# 2                       BUQUET SABAT DANIEL          104
# 3            BASURTO RODRIGUEZ AUREA CARMEN          128
# 4                 BAUTISTA MENDOZA GAMALIEL          182
# 5            BARRERA CEBALLOS JORGE ARMANDO          199
# 6                 AGUILAR SANCHEZ ALMA ROSA          189
# 7                       ARRIAGA PARRA MARIO           52
# 8               ARRIAGA ALEMAN JOSE ROBERTO          183
# 9             ARTEAGA NAVARRO JULIO ENRIQUE          129
# 10                  ARELLANO AGUILAR ANDRES           55
# 11             ALVAREZ TERRONES RITA DALILA          153
# 12             ANAYA SANCHEZ VICTOR ALFONSO          192
# 13              ARAIZA LEDEZMA GLORIA ELENA           58
# 14                    VITE MARTINEZ DOMINGO            2
# 15                 VALADEZ RODRIGUEZ MANUEL            3
# 16             ULLOA ARELLANO VICTOR MANUEL            4
# 17               TERRONES AYALA LUIS MANUEL          160
# 18                      TAPIA AGUILAR MARIA          155
# 19              SUAREZ MADARIAGA JORGE LUIS            8
# 20            SOLANA ORTIZ FRANCISCO JAVIER          169
# 21                  SOSA MARTINEZ CRISTOBAL          203
# 22                 SILVA URRUTIA JOSE ELIUD           10
# 23    SANDOVAL MIRANDA MARTHA LIZBETH SHAID          204
# 24                   SANCHEZ MUÑOZ MAXIMINO          173
# 25                    SANDOVAL LUNA LILIANA           91
# 26             SANCHEZ BARQUIN MIGUEL ANGEL          103
# 27                   SANCHEZ ALDANA ALBERTO           12
# 28                 RUIZ RAMOS JOSE FERNANDO          174
# 29                     ROSAS GARCIA ERNESTO          161
# ..                                      ...          ...
# 141                 VELAZQUEZ IBARRA KARINA          267
# 142           SANTAMARIA HARO AMOS EMMANUEL          268
# 143                     RIVERA ORTEGA MARIO          269
# 144            PEREZ MENDOZA CARLOS OCTAVIO          270
# 145                   MORALES GARCIA ISIDRO          271
# 146                   MARIN TELLEZ LEONARDO          272
# 147                 LARA RIVERA JESUS ANGEL          273
# 148              GUZMAN BOST JOSE FRANCISCO          274
# 149                  GARCIA MINJARES MANUEL          275
# 150                   CORONEL RAMIREZ WENDY          276
# 151                 BARRAGAN ROMERO GERARDO          277
# 152               BARRAGAN ANZURES HERCILIO          278
# 153  ARES DE PARGA REGALADO ANGELA MERCEDES          279
# 154                  ALCALA ALVAREZ ALBERTO          280
# 155                   RAMOS LOPEZ ARAM ISAI          281
# 156                 JIMENEZ NORIEGA LETICIA          149
# 157               JIMENEZ GUTIERREZ GUSTAVO          282
# 158               HERNANDEZ MONTOYA RICARDO          283
# 159            GARCIA GRANADOS ALAN OCTAVIO          284
# 160                   GALINDO CRUZ SALVADOR          285
# 161               DELGADO DIAZ CESAR ADRIAN          286
# 162             VENEGAS DEL ANGEL ALEJANDRO          287
# 163               ROMEU TORO MOISES ARMANDO          288
# 164                 PEÑA PEREZ JOSE ANTONIO          289
# 165                 GARCIA REYES ERICK IVAN          290
# 166    GARCIA MONTENEGRO RAYMUNDO ALEJANDRO          291
# 167                   DOMINGUEZ MEDINA IVAN          292
# 168                AGUILAR MALDONADO CINTLI          293
# 169                ARRIOLA PEÑA TANIA ANAID          294
# 170               AVILA AYALA ROCIO MARIBEL          295
#
# [171 rows x 2 columns]

# %%
df_plan_de_estudios[df_plan_de_estudios['SEMESTRE']==10]
# Out:
#                                   MATERIA  SEMESTRE
# 82            CALCULO DIFER. E INTEGRAL I        10
# 83             INTRODUCCION A COMPUTACION        10
# 84                   CONTABILIDAD GENERAL        10
# 85           APLICACIONES A MAT.FINANCRAS        10
# 86           INVESTIGACION DE OPERACIONES        10
# 87                       TEORIA DE JUEGOS        10
# 88          CALCULO DIFER. E INTEGRAL III        10
# 89                      ALGEBRA SUPERIOR         10
# 90                            FINANZAS II        10
# 91            SOCIEDAD-POL.DEL MEX.ACTUAL        10
# 92             METODOS-TECS.INVESTIGACION        10
# 93                 ECONOMIA MATEMATICA II        10
# 94           CALCULO DIFER. E INTEGRAL II        10
# 95                       ALGEBRA SUPERIOR        10
# 96                METODOS-TECS.DE ESTUDIO        10
# 97                    FINANZAS PUBLICAS I        10
# 98                   CALCULO ACTUARIAL II        10
# 99           ANALISIS ESTADOS FINANCIEROS        10
# 100                   SEGUROS DE PERSONAS        10
# 101          CALCULO ACT.MODELOS DINAMICS        10
# 102           PRINCIPIOS-PRAC.MERCADOTEC.        10
# 103          CALCULO DIFER. E INTEGRAL IV        10
# 104           ESTRUCTURA-PROCESAMTO.DATOS        10
# 105                ADMINISTRACION GENERAL        10
# 106          SEM. INVESTIGACION ACTUARIAL        10
# 107                   CALCULO ACTUARIAL I        10
# 108                     TEORIA DEL RIESGO        10
# 109                    TEORIA DE SISTEMAS        10
# 110            ORGANIZACION-PROGRAM.ADMVA        10
# 111                            FINANZAS I        10
# 112                 ANALISIS ECONOMETRICO        10
# 113                   GEOMETRIA ANALITICA        10
# 114                     METODOS NUMERICOS        10
# 115               MODELOS MICROECONOMICOS        10
# 116                DISEÑO DE EXPERIMENTOS        10
# 117                            DEMOGRAFIA        10
# 118                  FINANZAS PUBLICAS II        10
# 119                 ESTADISTICA BAYESIANA        10
# 120             ADMINISTRACION DEL RIESGO        10
# 121               PRONOSTICOS DE NEGOCIOS        10
# 122                       TORIA DE JUEGOS        10
# 123               PROGRAMACION MATEMATICA        10
# 124         TEORIA GRAFICAS-ANALIS. REDES        10
# 125                         COMPUTACION I        10
# 126                       SEGURO DE DA¥OS        10
# 127                        COMPUTACION II        10
# 128  SOCIEDAD Y POLITICA DL MEXICO ACTUAL        10
# 129                   ANALISIS MATEMATICO        10
# 130    FINANZAS CORPORATIVAS Y BURSATILES        10
# 131  APLICACION A LAS MATEMATIC. FINANCIE        10
# 132            MODELOS MICROECONOMETRICOS        10
# 133                        OPERACIONES II        10
# 134         ANALISIS DE DATOS CATEGORICOS        10
# 135     MATEMATICAS ACTUARIALES APLICADAS        10
# 136            ADMINISTRACION DEL RIESGO         10

# %%
df_base[df_base['Materia']=='2101']['Nombre']
# Out:
# 0      ALGEBRA SUPERIOR
# 14     ALGEBRA SUPERIOR
# 29     ALGEBRA SUPERIOR
# 66     ALGEBRA SUPERIOR
# 138    ALGEBRA SUPERIOR
# 164    ALGEBRA SUPERIOR
# 165    ALGEBRA SUPERIOR
# 204    ALGEBRA SUPERIOR
# 278    ALGEBRA SUPERIOR
# 301    ALGEBRA SUPERIOR
# 304    ALGEBRA SUPERIOR
# 336    ALGEBRA SUPERIOR
# 415    ALGEBRA SUPERIOR
# 442    ALGEBRA SUPERIOR
# 444    ALGEBRA SUPERIOR
# 471    ALGEBRA SUPERIOR
# 568    ALGEBRA SUPERIOR
# 572    ALGEBRA SUPERIOR
# 578    ALGEBRA SUPERIOR
# 582    ALGEBRA SUPERIOR
# 715    ALGEBRA SUPERIOR
# 743    ALGEBRA SUPERIOR
# 763    ALGEBRA SUPERIOR
# 925    ALGEBRA SUPERIOR
# 947    ALGEBRA SUPERIOR
# Name: Nombre, dtype: object

# %%
for i in range(1,8+1):
    print df_plan_de_estudios[df_plan_de_estudios['SEMESTRE']==i]
# Out:
#                             MATERIA  SEMESTRE
# 0  CALCULO DIFERENCIAL E INTEGRAL I         1
# 1                ALGEBRA SUPERIOR I         1
# 2             GEOMETRIA ANALITICA I         1
# 3         ALGORITMOS Y PROGRAMACION         1
# 4                    SEGURO DE VIDA         1
#                               MATERIA  SEMESTRE
# 5   CALCULO DIFERENCIAL E INTEGRAL II         2
# 6                 ALGEBRA SUPERIOR II         2
# 7              GEOMETRIA ANALITICA II         2
# 8    PROBLEMAS SOCIOECON. MEX. ACTUAL         2
# 9                      BASES DE DATOS         2
# 10                    SEGURO DE DAÑOS         2
# 11                           INGLES I         2
#                                MATERIA  SEMESTRE
# 12  CALCULO DIFERENCIAL E INTEGRAL III         3
# 13                    ALGEBRA LINEAL I         3
# 14                        CONTABILIDAD         3
# 15                      PROBABILIDAD I         3
# 16           MATEMATICAS FINANCIERAS I         3
# 17                           INGLES II         3
#                               MATERIA  SEMESTRE
# 18  CALCULO DIFERENCIAL E INTEGRAL IV         4
# 19                  ALGEBRA LINEAL II         4
# 20     INVESTIGACION DE OPERACIONES I         4
# 21                      ESTADISTICA I         4
# 22         MATEMATICAS FINANCIERAS II         4
# 23                         INGLES III         4
#                       MATERIA  SEMESTRE
# 24   ECUACIONES DIFERENCIALES         5
# 25            PROBABILIDAD II         5
# 26             ESTADISTICA II         5
# 27      FINANZAS CORPORATIVAS         5
# 28  MATEMATICAS ACTUARIALES I         5
# 29                  INGLES IV         5
#                              MATERIA  SEMESTRE
# 30             ANALISIS MATEMATICO I         6
# 31             ECONOMIA MATEMATICA I         6
# 32           PROCESOS ESTOCASTICOS I         6
# 33                   ESTADISTICA III         6
# 34  APLICACION A LAS MATEMATIC.FINAN         6
# 35        MATEMATICAS ACTUARIALES II         6
# 36                          INGLES V         6
#                      MATERIA  SEMESTRE
# 37         ANALISIS NUMERICO         7
# 38   DEMOGRAFIA MATEMATICA I         7
# 39       TEORIA DEL RIESGO I         7
# 40  ADMINISTRACION ACTUARIAL         7
# 41                 INGLES VI         7
# 42                OPTATIVA_1         7
# 43                OPTATIVA_2         7
#                              MATERIA  SEMESTRE
# 44        SEMINARIO DE INVESTIGACION         8
# 45         ADMINISTRACION DE RIESGOS         8
# 46  MATEMATICAS ACTUARIALES PENSIONE         8
# 47                        OPTATIVA_3         8
# 48                       OPTATIVAS_4         8
# 49                       OPTATIVAS_5         8

# %%
a=dict()

# %%
for i in range(1,9):
    a[i]=df_plan_de_estudios[df_plan_de_estudios['SEMESTRE']==i]

# %%
a[1]
# Out:
#                             MATERIA  SEMESTRE
# 0  CALCULO DIFERENCIAL E INTEGRAL I         1
# 1                ALGEBRA SUPERIOR I         1
# 2             GEOMETRIA ANALITICA I         1
# 3         ALGORITMOS Y PROGRAMACION         1
# 4                    SEGURO DE VIDA         1

# %%
b=dict()
h=dict()
c=dict()

# %%
df_plan_de_estudios['MATERIA'].unique().tolist()
# Out:
# ['CALCULO DIFERENCIAL E INTEGRAL I',
#  'ALGEBRA SUPERIOR I',
#  'GEOMETRIA ANALITICA I',
#  'ALGORITMOS Y PROGRAMACION',
#  'SEGURO DE VIDA',
#  'CALCULO DIFERENCIAL E INTEGRAL II',
#  'ALGEBRA SUPERIOR II',
#  'GEOMETRIA ANALITICA II',
#  'PROBLEMAS SOCIOECON. MEX. ACTUAL',
#  'BASES DE DATOS',
#  'SEGURO DE DA\xc3\x91OS',
#  'INGLES I',
#  'CALCULO DIFERENCIAL E INTEGRAL III',
#  'ALGEBRA LINEAL I',
#  'CONTABILIDAD',
#  'PROBABILIDAD I',
#  'MATEMATICAS FINANCIERAS I',
#  'INGLES II',
#  'CALCULO DIFERENCIAL E INTEGRAL IV',
#  'ALGEBRA LINEAL II',
#  'INVESTIGACION DE OPERACIONES I',
#  'ESTADISTICA I',
#  'MATEMATICAS FINANCIERAS II',
#  'INGLES III',
#  'ECUACIONES DIFERENCIALES',
#  'PROBABILIDAD II',
#  'ESTADISTICA II',
#  'FINANZAS CORPORATIVAS',
#  'MATEMATICAS ACTUARIALES I',
#  'INGLES IV',
#  'ANALISIS MATEMATICO I',
#  'ECONOMIA MATEMATICA I',
#  'PROCESOS ESTOCASTICOS I',
#  'ESTADISTICA III',
#  'APLICACION A LAS MATEMATIC.FINAN',
#  'MATEMATICAS ACTUARIALES II',
#  'INGLES V',
#  'ANALISIS NUMERICO',
#  'DEMOGRAFIA MATEMATICA I',
#  'TEORIA DEL RIESGO I',
#  'ADMINISTRACION ACTUARIAL',
#  'INGLES VI',
#  'OPTATIVA_1',
#  'OPTATIVA_2',
#  'SEMINARIO DE INVESTIGACION',
#  'ADMINISTRACION DE RIESGOS',
#  'MATEMATICAS ACTUARIALES PENSIONE',
#  'OPTATIVA_3',
#  'OPTATIVAS_4',
#  'OPTATIVAS_5',
#  'ANALISIS MATEMATICO II',
#  'ANALISIS MULTIVARIADO',
#  'ANALISIS DE REGRESION',
#  'AUDITORIA ACTUARIAL',
#  'CONTABILIDAD DE SEGUROS',
#  'DEMOGRAFIA MATEMATICA II',
#  'DERIVADOS',
#  'ESTADISTICA DE SEGUROS',
#  'EVALUACION DE PROYECTOS',
#  'FIANZAS',
#  'FINANZAS INTERNACIONALES',
#  'FINANZAS MATEMATICAS',
#  'MUESTREO',
#  'PROCESOS ESTOCASTICOS II',
#  'REASEGURO',
#  'SEGURO DE PERSONAS',
#  'SIMULACION ESTOCASTICA',
#  'TEMAS SELECTOS DE COMPUTACION',
#  'TEMAS SELECTOS DE MATEMATICAS',
#  'TEMAS SELECTOS D PROBAB.Y ESTADI',
#  'TEMAS SELECTOS DE SEGUROS',
#  'TEORIA DE LA MEDIDA',
#  'VARIABLE COMPLEJA',
#  'PENSIONES',
#  'SEMINARIO DE TITULACION',
#  'FINANZAS PUBLICAS',
#  'LEGISLACION DE SEGUROS',
#  'MODELOS Y SIMULACION',
#  'PLANEACION FINANCIERA',
#  'ANALISIS DE ESTADOS FINANCIEROS',
#  'PRESUPUESTO DE CAPITAL',
#  'SERIES DE TIEMPO',
#  'CALCULO DIFER. E INTEGRAL I',
#  'INTRODUCCION A COMPUTACION',
#  'CONTABILIDAD GENERAL',
#  'APLICACIONES A MAT.FINANCRAS',
#  'INVESTIGACION DE OPERACIONES',
#  'TEORIA DE JUEGOS',
#  'CALCULO DIFER. E INTEGRAL III',
#  'ALGEBRA SUPERIOR ',
#  'FINANZAS II',
#  'SOCIEDAD-POL.DEL MEX.ACTUAL',
#  'METODOS-TECS.INVESTIGACION',
#  'ECONOMIA MATEMATICA II',
#  'CALCULO DIFER. E INTEGRAL II',
#  'ALGEBRA SUPERIOR',
#  'METODOS-TECS.DE ESTUDIO',
#  'FINANZAS PUBLICAS I',
#  'CALCULO ACTUARIAL II',
#  'ANALISIS ESTADOS FINANCIEROS',
#  'SEGUROS DE PERSONAS',
#  'CALCULO ACT.MODELOS DINAMICS',
#  'PRINCIPIOS-PRAC.MERCADOTEC.',
#  'CALCULO DIFER. E INTEGRAL IV',
#  'ESTRUCTURA-PROCESAMTO.DATOS',
#  'ADMINISTRACION GENERAL',
#  'SEM. INVESTIGACION ACTUARIAL',
#  'CALCULO ACTUARIAL I',
#  'TEORIA DEL RIESGO',
#  'TEORIA DE SISTEMAS',
#  'ORGANIZACION-PROGRAM.ADMVA',
#  'FINANZAS I',
#  'ANALISIS ECONOMETRICO',
#  'GEOMETRIA ANALITICA',
#  'METODOS NUMERICOS',
#  'MODELOS MICROECONOMICOS',
#  'DISE\xc3\x91O DE EXPERIMENTOS',
#  'DEMOGRAFIA',
#  'FINANZAS PUBLICAS II',
#  'ESTADISTICA BAYESIANA',
#  'ADMINISTRACION DEL RIESGO',
#  'PRONOSTICOS DE NEGOCIOS',
#  'TORIA DE JUEGOS',
#  'PROGRAMACION MATEMATICA',
#  'TEORIA GRAFICAS-ANALIS. REDES',
#  'COMPUTACION I',
#  'SEGURO DE DA\xc2\xa5OS',
#  'COMPUTACION II',
#  'SOCIEDAD Y POLITICA DL MEXICO ACTUAL',
#  'ANALISIS MATEMATICO',
#  'FINANZAS CORPORATIVAS Y BURSATILES',
#  'APLICACION A LAS MATEMATIC. FINANCIE',
#  'MODELOS MICROECONOMETRICOS',
#  'OPERACIONES II',
#  'ANALISIS DE DATOS CATEGORICOS',
#  'MATEMATICAS ACTUARIALES APLICADAS',
#  'ADMINISTRACION DEL RIESGO ']

# %%
b=dict()
h=dict()
c=dict()
for i in df_plan_de_estudios['MATERIA'].unique().tolist():
    b[i]=df_base[df_base['Nombre']==i]
    b[i]['Ind_Aprob']=b[i]['APROBADOS']/b[i]['Inscritos']
# Out:
# /home/cesar5484/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
def proba_aproba(i):
    return np.random.choice(b[i]['Ind_Aprob'],p=map(lambda x: 1/len(b[i]['Ind_Aprob']), range(0,len(b[i]['Ind_Aprob']))))

# %%
u=dict()
klm=dict()
for i in df_plan_de_estudios['MATERIA'][df_plan_de_estudios['SEMESTRE']==9].unique().tolist():
    u[i]=df_base[df_base['Nombre']==i]
    u[i]['Ind_Aprob']=u[i]['APROBADOS']/u[i]['Inscritos']
def proba_aproba_optativa():
    rst=[]
    for i in df_plan_de_estudios['MATERIA'][df_plan_de_estudios['SEMESTRE']==9].unique().tolist():
        if len(u[i]['Ind_Aprob'])==0:
            safsdfs=0
        else:
            rst.append(np.random.choice(u[i]['Ind_Aprob'],p=map(lambda x: 1/len(u[i]['Ind_Aprob']), range(0,len(u[i]['Ind_Aprob'])))))
    return float(pd.DataFrame(rst).mean())
# Out:
# /home/cesar5484/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
def aprobacion_grupo():
    c=dict()
    for j in range(1,7):
        d=[]
        for i in a[j]['MATERIA'].tolist():
            d.append(proba_aproba(i))
        o=a[j]['MATERIA'].tolist()
        abcd=pd.DataFrame(d,columns=['proba_aproba'])
        ou=pd.DataFrame(o,columns=['MATERIA'])
        c[j]=pd.concat([ou,abcd],axis=1)
    return c

# %%
def meter_1(ingreso):
    id_alumno=[]
    grupo=[]
    for i in range(1,ingreso+1):
        id_alumno.append(i)
        grupo.append(np.random.choice(range(1,7+1),p=map(lambda x: 1/7, range(0,7))))
    id_alumno=pd.DataFrame(id_alumno)
    id_alumno.rename(columns={0:'id_alumno'},inplace=True)
    grupo=pd.DataFrame(grupo)
    grupo.rename(columns={0:'grupo'},inplace=True)
    return pd.concat([id_alumno,grupo],axis=1)

# %%
def info_1(meter_12):
    grupos=dict()
    grupos[0]=[]
    for i in range(1,7+1):
        grupos[i]=aprobacion_grupo()[1]
        for k in grupos[i]['MATERIA'].tolist():
            if i==1:
                meter_12[''+k+'']=map(lambda x: 0, range(0,len(meter_12['id_alumno'].tolist())))
            pro=float(grupos[i][grupos[i]['MATERIA']==k]['proba_aproba'])
            for j in meter_12[meter_12['grupo']==i]['id_alumno'].tolist():
                meter_12[''+k+''][meter_12['id_alumno']==j]=np.random.choice([1,0],p=[pro,1-pro])
    return meter_12,grupos

def info_2(meter_12):
    grupos=dict()
    grupos[0]=[]
    for i in range(1,7+1):
        grupos[i]=aprobacion_grupo()[2]
        for k in grupos[i]['MATERIA'].tolist():
            if i==1:
                meter_12[''+k+'']=map(lambda x: 0, range(0,len(meter_12['id_alumno'].tolist())))
            pro=float(grupos[i][grupos[i]['MATERIA']==k]['proba_aproba'])
            for j in meter_12[meter_12['grupo']==i]['id_alumno'].tolist():
                meter_12[''+k+''][meter_12['id_alumno']==j]=np.random.choice([1,0],p=[pro,1-pro])
    return meter_12,grupos

def info_3(meter_12):
    grupos=dict()
    grupos[0]=[]
    for i in range(1,7+1):
        grupos[i]=aprobacion_grupo()[3]
        for k in grupos[i]['MATERIA'].tolist():
            if i==1:
                meter_12[''+k+'']=map(lambda x: 0, range(0,len(meter_12['id_alumno'].tolist())))
            pro=float(grupos[i][grupos[i]['MATERIA']==k]['proba_aproba'])
            for j in meter_12[meter_12['grupo']==i]['id_alumno'].tolist():
                meter_12[''+k+''][meter_12['id_alumno']==j]=np.random.choice([1,0],p=[pro,1-pro])
    return meter_12,grupos

def info_4(meter_12):
    grupos=dict()
    grupos[0]=[]
    for i in range(1,7+1):
        grupos[i]=aprobacion_grupo()[4]
        for k in grupos[i]['MATERIA'].tolist():
            if i==1:
                meter_12[''+k+'']=map(lambda x: 0, range(0,len(meter_12['id_alumno'].tolist())))
            pro=float(grupos[i][grupos[i]['MATERIA']==k]['proba_aproba'])
            for j in meter_12[meter_12['grupo']==i]['id_alumno'].tolist():
                meter_12[''+k+''][meter_12['id_alumno']==j]=np.random.choice([1,0],p=[pro,1-pro])
    return meter_12,grupos

def info_5(meter_12):
    grupos=dict()
    grupos[0]=[]
    for i in range(1,7+1):
        grupos[i]=aprobacion_grupo()[5]
        for k in grupos[i]['MATERIA'].tolist():
            if i==1:
                meter_12[''+k+'']=map(lambda x: 0, range(0,len(meter_12['id_alumno'].tolist())))
            pro=float(grupos[i][grupos[i]['MATERIA']==k]['proba_aproba'])
            for j in meter_12[meter_12['grupo']==i]['id_alumno'].tolist():
                meter_12[''+k+''][meter_12['id_alumno']==j]=np.random.choice([1,0],p=[pro,1-pro])
    return meter_12,grupos

def info_6(meter_12):
    grupos=dict()
    grupos[0]=[]
    for i in range(1,7+1):
        grupos[i]=aprobacion_grupo()[6]
        for k in grupos[i]['MATERIA'].tolist():
            if i==1:
                meter_12[''+k+'']=map(lambda x: 0, range(0,len(meter_12['id_alumno'].tolist())))
            pro=float(grupos[i][grupos[i]['MATERIA']==k]['proba_aproba'])
            for j in meter_12[meter_12['grupo']==i]['id_alumno'].tolist():
                meter_12[''+k+''][meter_12['id_alumno']==j]=np.random.choice([1,0],p=[pro,1-pro])
    return meter_12,grupos

# %%
def aprobacion_grupo_ultimos():
    c=dict()
    d=[]
    for i in a[7]['MATERIA'].tolist():
        if i=='OPTATIVA_1' or i=='OPTATIVA_2' or i=='OPTATIVA_3'or i=='OPTATIVA_4'or i=='OPTATIVA_5':
            gh=0
            d.append(proba_aproba_optativa())
        else:
            d.append(proba_aproba(i))
    o=a[7]['MATERIA'].tolist()
    abcd=pd.DataFrame(d,columns=['proba_aproba'])
    ou=pd.DataFrame(o,columns=['MATERIA'])
    c[7]=pd.concat([ou,abcd],axis=1)
    return c

# %%
def aprobacion_grupo_ultimos2():
    c=dict()
    d=[]
    for i in a[8]['MATERIA'].tolist():
        if i=='OPTATIVA_1' or i=='OPTATIVA_2' or i=='OPTATIVA_3'or i=='OPTATIVAS_4'or i=='OPTATIVAS_5':
            gh=0
            d.append(proba_aproba_optativa())
        else:
            d.append(proba_aproba(i))
    o=a[8]['MATERIA'].tolist()
    abcd=pd.DataFrame(d,columns=['proba_aproba'])
    ou=pd.DataFrame(o,columns=['MATERIA'])
    c[8]=pd.concat([ou,abcd],axis=1)
    return c

# %%
def info_7(meter_12):
    grupos=dict()
    grupos[0]=[]
    for i in range(1,7+1):
        grupos[i]=aprobacion_grupo_ultimos()[7]
        for k in grupos[i]['MATERIA'].tolist():
            if i==1:
                meter_12[''+k+'']=map(lambda x: 0, range(0,len(meter_12['id_alumno'].tolist())))
            pro=float(grupos[i][grupos[i]['MATERIA']==k]['proba_aproba'])
            for j in meter_12[meter_12['grupo']==i]['id_alumno'].tolist():
                meter_12[''+k+''][meter_12['id_alumno']==j]=np.random.choice([1,0],p=[pro,1-pro])
    return meter_12,grupos

def info_8(meter_12):
    grupos=dict()
    grupos[0]=[]
    for i in range(1,7+1):
        grupos[i]=aprobacion_grupo_ultimos2()[8]
        for k in grupos[i]['MATERIA'].tolist():
            if i==1:
                meter_12[''+k+'']=map(lambda x: 0, range(0,len(meter_12['id_alumno'].tolist())))
            pro=float(grupos[i][grupos[i]['MATERIA']==k]['proba_aproba'])
            for j in meter_12[meter_12['grupo']==i]['id_alumno'].tolist():
                meter_12[''+k+''][meter_12['id_alumno']==j]=np.random.choice([1,0],p=[pro,1-pro])
    return meter_12,grupos

# %%
def GENERACIONES(n):
    gen=dict()
    egre=[]
    for k in range(1,n+1):
        ingreso=sim_ingreso(1,2015)[0]
        semestre=dict()
        semestre[1]=ingreso
        for i in range(1,8):
            if i==1:
                hij=info_1(meter_1(semestre[i]))
            elif i==2:
                hij=info_2(meter_1(semestre[i]))
            elif i==3:
                hij=info_3(meter_1(semestre[i]))
            elif i==4:
                hij=info_4(meter_1(semestre[i]))
            elif i==5:
                hij=info_5(meter_1(semestre[i]))
            elif i==6: 
                hij=info_6(meter_1(semestre[i]))
            elif i==7:
                hij=info_7(meter_1(semestre[i]))
            else:
                hij=info_8(meter_1(semestre[i]))

            if i==1:
                semestre[i+1]=hij[0][hij[0]['CALCULO DIFERENCIAL E INTEGRAL I']==1].count()[2]
            elif i==2:
                semestre[i+1]=hij[0][hij[0]['CALCULO DIFERENCIAL E INTEGRAL II']==1].count()[2]
            elif i==3:
                semestre[i+1]=hij[0][hij[0]['PROBABILIDAD I']==1].count()[2]
            elif i==4:
                semestre[i+1]=hij[0][hij[0]['ESTADISTICA I']==1].count()[2]
            elif i==5:
                semestre[i+1]=hij[0][hij[0]['PROBABILIDAD II']==1].count()[2]
            elif i==6:
                semestre[i+1]=hij[0][hij[0]['PROCESOS ESTOCASTICOS I']==1].count()[2]
            elif i==7:
                semestre[i+1]=hij[0][hij[0]['TEORIA DEL RIESGO I']==1].count()[2]
            else:
                semestre[i+1]=hij[0][hij[0]['ADMINISTRACION DE RIESGOS']==1].count()[2]
        gen[k]=semestre
        egre.append(semestre[8])
    return gen,egre

# %%
n=1
RESULTADO=GENERACIONES(n)

# %%
RESULTADO
# Out:
# ({1: {1: 487, 2: 203, 3: 101, 4: 71, 5: 50, 6: 31, 7: 19, 8: 18}}, [18])

# %%
pd.DataFrame(RESULTADO[1]).mean()
# Out:
# 0    24.666667
# dtype: float64

# %%
sns.distplot(pd.DataFrame(RESULTADO[1]),hist=True,kde=True,bins=25,color='blue')

# %%
f = Fitter(pd.DataFrame(RESULTADO[1]))
f.fit()
# Out:
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.py:2303: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu
# Searching best parameters for distribution alpha (error 0.0645028969867)
# Searching best parameters for distribution anglit (error 0.0858115720869)
# Searching best parameters for distribution arcsine (error 0.117159811799)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:5252: RuntimeWarning: divide by zero encountered in double_scalars
#   return chi**3 / (_norm_pdf_C * _argus_phi(chi)) * x * np.sqrt(y) * np.exp(-chi**2 * y / 2)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:404: RuntimeWarning: invalid value encountered in sqrt
#   sk = 2*(b-a)*np.sqrt(a + b + 1) / (a + b + 2) / np.sqrt(a*b)
# Searching best parameters for distribution argus (error 0.100228083513)
# Searching best parameters for distribution beta (error 0.0644284644731)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:554: RuntimeWarning: divide by zero encountered in true_divide
#   a/(b-1.0),
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:558: RuntimeWarning: divide by zero encountered in true_divide
#   a*(a+1.0)/((b-2.0)*(b-1.0)),
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.py:1037: RuntimeWarning: invalid value encountered in subtract
#   mu2 = mu2p - mu * mu
# Searching best parameters for distribution betaprime (error 0.064421421827)
# Searching best parameters for distribution bradford (error 0.0925264790092)
# Searching best parameters for distribution burr (error 0.0647591790234)
# Searching best parameters for distribution burr12 (error 0.0646028794273)
# Searching best parameters for distribution cauchy (error 0.068866398614)
# Searching best parameters for distribution chi (error 0.350188930273)
# Searching best parameters for distribution chi2 (error 0.0644302630672)
# Searching best parameters for distribution cosine (error 0.0785308974673)
# Searching best parameters for distribution dgamma (error 0.0655652808434)
# Searching best parameters for distribution dweibull (error 0.065127352407)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.3000000000000007.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6999999999999993.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.7999999999999989.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.9499999999999993.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.2666666666666675.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.8416666666666668.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.9444444444444464.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.9486111111111111.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.1240740740740751.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.053472222222223.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.087037037037037.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0524305555555555.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.9814814814814818.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0354745370370377.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0586033950617288.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0146508487654327.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.9809863683127586.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0345695087448563.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.9973390346364859.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0259406614369002.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0256892646890723.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0229296607081624.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.9980107060185199.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0254298080632722.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0113173189586186.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0417918589725286.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.062687788458792.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0507909000231814.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0211857142247593.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0338490150261848.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0386103973787471.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0549818000268827.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0718798429279435.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.067672384493294.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0423048573929616.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0653739754835438.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0586830809573442.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0734533285463037.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0497072263659728.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0778752427745459.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0742917937549645.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0996573599389965.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0621947597592287.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0610356881868785.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0526159108930457.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0759434568206272.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0828178053513273.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0649475315353349.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0672835970902428.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0642953184705544.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0699837118135962.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0811048222960977.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0660529717141838.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0740364964753608.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.074038238193185.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0832924892785982.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0703628511052869.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0728569647409989.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0731522831040454.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0722692308779473.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.072564742765195.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0768221025372267.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0719776639632723.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.074721344821449.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0741083163355736.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0754548819811216.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0732872775691771.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0769150365203135.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0732120071025326.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0741868446593177.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0742261088211897.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0711806294000583.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0747527499654854.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0748137902490473.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0736689057391446.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0751936598067653.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0737074202785912.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0738992059961632.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0741149349935295.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0747144977525922.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0739303037425065.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0748245721890903.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0748901489378575.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0742242295748117.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0746744865355211.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0742438761784392.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0736756286997871.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0745865188783394.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0750729506523582.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0742159654699694.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0747407710774475.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0743680999031913.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0741059029654778.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0745323406430103.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0741577517991079.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0744793271085316.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0747038796331871.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0743379440107734.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.07425790670532.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0744637321585877.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0744859022820705.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0743975504979115.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0743201573363175.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.074439534665478.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.074529267537212.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0744814366556019.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value array(6.074463732158588).
#   RuntimeWarning)
# Searching best parameters for distribution erlang (error 0.0644302659412)
# Searching best parameters for distribution expon (error 0.100897322324)
# Searching best parameters for distribution exponnorm (error 0.0647616938001)
# Searching best parameters for distribution exponpow (error 0.262419833612)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:1232: RuntimeWarning: invalid value encountered in add
#   negxc + sc.xlogy(c - 1.0, x))
# Searching best parameters for distribution exponweib (error 0.292773232658)
# Searching best parameters for distribution f (error 0.0644217822357)
# Searching best parameters for distribution fatiguelife (error 0.0644044815066)
# Searching best parameters for distribution fisk (error 0.0648549923397)
# Searching best parameters for distribution foldcauchy (error 0.0677758491493)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_distn_infrastructure.py:1612: RuntimeWarning: divide by zero encountered in log
#   return log(self._pdf(x, *args))
# Searching best parameters for distribution foldnorm (error 0.0872027587133)
# Searching best parameters for distribution frechet_l (error 0.0644634850486)
# Searching best parameters for distribution frechet_r (error 0.310788147873)
# Searching best parameters for distribution gamma (error 0.0644302653053)
# Searching best parameters for distribution gausshyper (error 0.0656158276857)
# Searching best parameters for distribution genexpon (error 0.0672399797198)
# Searching best parameters for distribution genextreme (error 0.0644634743877)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:1894: RuntimeWarning: invalid value encountered in true_divide
#   np.sign(c)*(-g3+(g2+2*g2mg12)*g1)/((g2mg12)**(3./2.)))
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:1899: RuntimeWarning: invalid value encountered in true_divide
#   (g4+(-4*g3+3*(g2+g2mg12)*g1)*g1)/((g2mg12)**2))
# Searching best parameters for distribution gengamma (error 0.0644134407345)
# Searching best parameters for distribution genhalflogistic (error 0.0792862038402)
# Searching best parameters for distribution genlogistic (error 0.0644659591453)
# Searching best parameters for distribution gennorm (error 0.0670466680809)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:1753: RuntimeWarning: divide by zero encountered in true_divide
#   val = val + cnk * (-1) ** ki / (1.0 - c * ki)
# Searching best parameters for distribution genpareto (error 0.0882253612315)
# Searching best parameters for distribution gilbrat (error 0.0849881044747)
# Searching best parameters for distribution gompertz (error 0.0701524508078)
# Searching best parameters for distribution gumbel_l (error 0.0764944681214)
# Searching best parameters for distribution gumbel_r (error 0.0644533661895)
# Searching best parameters for distribution halfcauchy (error 0.0961311342543)
# Searching best parameters for distribution halfgennorm (error 0.130815125216)
# Searching best parameters for distribution halflogistic (error 0.0893646219969)
# Searching best parameters for distribution halfnorm (error 0.0870420342041)
# Searching best parameters for distribution hypsecant (error 0.066784032449)
# Searching best parameters for distribution invgamma (error 0.0644511787807)
# Searching best parameters for distribution invgauss (error 0.0644060668032)
# Searching best parameters for distribution invweibull (error 0.0644545344558)
# Searching best parameters for distribution johnsonsb (error 0.0644065406617)
# Searching best parameters for distribution johnsonsu (error 0.0644257138252)
# Searching best parameters for distribution kappa3 (error 0.0789041513808)
# Searching best parameters for distribution kappa4 (error 0.0954342153558)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/integrate/quadpack.py:364: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   warnings.warn(msg, IntegrationWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:35: RuntimeWarning: floating point number truncated to an integer
#   return 1.0 - sc.smirnov(n, x)
# Searching best parameters for distribution ksone (error nan)
# Searching best parameters for distribution kstwobign (error 0.0644392572638)
# Searching best parameters for distribution laplace (error 0.0680215353852)
# Searching best parameters for distribution levy (error 0.0966401442119)
# Searching best parameters for distribution levy_l (error 0.115216038706)
# (<type 'exceptions.NotImplementedError'>, NotImplementedError(), <traceback object at 0x7f49781b4908>)
# SKIPPED levy_stable distribution (taking more than 10 seconds)
# Searching best parameters for distribution loggamma (error 0.0679970669622)
# Searching best parameters for distribution logistic (error 0.0668690075246)
# Searching best parameters for distribution loglaplace (error 0.0665001876788)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:3157: RuntimeWarning: divide by zero encountered in true_divide
#   return c**2 / (c**2 - n**2)
# Searching best parameters for distribution lognorm (error 0.0644237480745)
# Searching best parameters for distribution lomax (error 0.100780007598)
# Searching best parameters for distribution maxwell (error 0.0651925247238)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/integrate/quadpack.py:364: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   warnings.warn(msg, IntegrationWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/integrate/quadpack.py:364: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   warnings.warn(msg, IntegrationWarning)
# Searching best parameters for distribution mielke (error 0.0647576021023)
# Searching best parameters for distribution nakagami (error 0.14432786535)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:3684: RuntimeWarning: divide by zero encountered in power
#   return 2*nu**nu/sc.gamma(nu)*(x**(2*nu-1.0))*np.exp(-nu*x*x)
# Searching best parameters for distribution ncf (error 0.0644073734371)
# Searching best parameters for distribution nct (error 0.0644895165705)
# Searching best parameters for distribution ncx2 (error 0.0829231260479)
# Searching best parameters for distribution norm (error 0.0677153222457)
# Searching best parameters for distribution pareto (error 0.16664763331)
# Searching best parameters for distribution pearson3 (error 0.0644302715939)
# Searching best parameters for distribution powerlaw (error 0.0986072247771)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:4281: RuntimeWarning: divide by zero encountered in power
#   pow(_norm_cdf(-np.log(x)/s), c*1.0-1.0))
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:4281: RuntimeWarning: invalid value encountered in multiply
#   pow(_norm_cdf(-np.log(x)/s), c*1.0-1.0))
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:4281: RuntimeWarning: overflow encountered in power
#   pow(_norm_cdf(-np.log(x)/s), c*1.0-1.0))
# Searching best parameters for distribution powerlognorm (error 0.0904318716293)
# Searching best parameters for distribution powernorm (error 0.0648334965513)
# Searching best parameters for distribution rayleigh (error 0.0668536215315)
# Searching best parameters for distribution rdist (error 0.0677184988884)
# Searching best parameters for distribution recipinvgauss (error 0.0644040263436)
# Searching best parameters for distribution reciprocal (error 0.1333001068)
# Searching best parameters for distribution rice (error 0.0668536221153)
# (<type 'exceptions.TypeError'>, TypeError('unbound method fit() must be called with rv_continuous instance as first argument (got ndarray instance instead)',), <traceback object at 0x7f49783b4830>)
# SKIPPED rv_continuous distribution (taking more than 10 seconds)
# (<type 'exceptions.TypeError'>, TypeError('unbound method fit() must be called with rv_histogram instance as first argument (got ndarray instance instead)',), <traceback object at 0x7f497813ce60>)
# SKIPPED rv_histogram distribution (taking more than 10 seconds)
# Searching best parameters for distribution semicircular (error 0.0913202372434)
# Searching best parameters for distribution skewnorm (error 0.0645560044897)
# Searching best parameters for distribution t (error 0.0670956152399)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:4685: RuntimeWarning: divide by zero encountered in true_divide
#   choicelist = [u * x / c, u, u * (1 - x) / (1 - d)]
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:4734: RuntimeWarning: divide by zero encountered in true_divide
#   return np.where(x < c, 2*x/c, 2*(1-x)/(1-c))
# Searching best parameters for distribution trapz (error 0.120123206213)
# Searching best parameters for distribution triang (error 0.072050683634)
# Searching best parameters for distribution truncexpon (error 0.0917088293647)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:4838: RuntimeWarning: divide by zero encountered in log
#   self._logdelta = np.log(self._delta)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:4838: RuntimeWarning: invalid value encountered in log
#   self._logdelta = np.log(self._delta)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:4896: RuntimeWarning: divide by zero encountered in power
#   Px = Fx**(lam-1.0) + (np.asarray(1-Fx))**(lam-1.0)
# Searching best parameters for distribution truncnorm (error 0.1333001068)
# Searching best parameters for distribution tukeylambda (error 0.0670409151102)
# Searching best parameters for distribution uniform (error 0.097700249199)
# Searching best parameters for distribution vonmises (error 1.26702479684e+62)
# Searching best parameters for distribution vonmises_line (error 0.100748050204)
# Searching best parameters for distribution wald (error 0.0801772436468)
# Searching best parameters for distribution weibull_max (error 0.0644634850486)
# Searching best parameters for distribution weibull_min (error 0.310788147873)
# Searching best parameters for distribution wrapcauchy (error nan)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/optimize/optimize.py:528: RuntimeWarning: invalid value encountered in subtract
#   numpy.max(numpy.abs(fsim[0] - fsim[1:])) <= fatol):

# %%
f.summary(Nbest=10)
# Out:
#                sumsquare_error
# recipinvgauss         0.064404
# fatiguelife           0.064404
# invgauss              0.064406
# johnsonsb             0.064407
# ncf                   0.064407
# gengamma              0.064413
# betaprime             0.064421
# f                     0.064422
# lognorm               0.064424
# johnsonsu             0.064426

# %%
RESULTADO=GENERACIONES(10000)

# %%
RESULTADO
# Out:
# ({1: {1: 462, 2: 208, 3: 149, 4: 89, 5: 53, 6: 35, 7: 31, 8: 26},
#   2: {1: 475, 2: 169, 3: 92, 4: 46, 5: 24, 6: 17, 7: 13, 8: 12},
#   3: {1: 462, 2: 158, 3: 79, 4: 41, 5: 20, 6: 13, 7: 12, 8: 10},
#   4: {1: 558, 2: 245, 3: 147, 4: 100, 5: 68, 6: 60, 7: 43, 8: 43},
#   5: {1: 531, 2: 176, 3: 116, 4: 74, 5: 43, 6: 30, 7: 26, 8: 23},
#   6: {1: 510, 2: 200, 3: 132, 4: 68, 5: 31, 6: 23, 7: 18, 8: 16},
#   7: {1: 488, 2: 181, 3: 130, 4: 75, 5: 41, 6: 20, 7: 16, 8: 13},
#   8: {1: 486, 2: 177, 3: 103, 4: 77, 5: 34, 6: 22, 7: 14, 8: 14},
#   9: {1: 419, 2: 204, 3: 145, 4: 96, 5: 53, 6: 42, 7: 27, 8: 25},
#   10: {1: 402, 2: 128, 3: 69, 4: 45, 5: 22, 6: 16, 7: 12, 8: 11},
#   11: {1: 432, 2: 163, 3: 99, 4: 52, 5: 21, 6: 16, 7: 12, 8: 10},
#   12: {1: 444, 2: 209, 3: 111, 4: 72, 5: 39, 6: 30, 7: 16, 8: 15},
#   13: {1: 462, 2: 271, 3: 173, 4: 143, 5: 86, 6: 60, 7: 41, 8: 35},
#   14: {1: 428, 2: 211, 3: 114, 4: 64, 5: 32, 6: 22, 7: 20, 8: 19},
#   15: {1: 470, 2: 176, 3: 99, 4: 55, 5: 32, 6: 23, 7: 20, 8: 18},
#   16: {1: 518, 2: 221, 3: 115, 4: 73, 5: 40, 6: 37, 7: 29, 8: 25},
#   17: {1: 535, 2: 149, 3: 91, 4: 37, 5: 14, 6: 13, 7: 13, 8: 12},
#   18: {1: 568, 2: 215, 3: 107, 4: 70, 5: 43, 6: 30, 7: 24, 8: 22},
#   19: {1: 468, 2: 195, 3: 112, 4: 70, 5: 48, 6: 38, 7: 30, 8: 30},
#   20: {1: 509, 2: 210, 3: 111, 4: 66, 5: 34, 6: 17, 7: 16, 8: 15},
#   21: {1: 486, 2: 279, 3: 142, 4: 85, 5: 29, 6: 25, 7: 22, 8: 19},
#   22: {1: 511, 2: 152, 3: 100, 4: 58, 5: 35, 6: 27, 7: 21, 8: 16},
#   23: {1: 514, 2: 227, 3: 133, 4: 64, 5: 24, 6: 18, 7: 17, 8: 12},
#   24: {1: 434, 2: 186, 3: 119, 4: 73, 5: 28, 6: 20, 7: 20, 8: 16},
#   25: {1: 539, 2: 216, 3: 153, 4: 116, 5: 80, 6: 62, 7: 52, 8: 45},
#   26: {1: 563, 2: 265, 3: 140, 4: 80, 5: 29, 6: 22, 7: 18, 8: 16},
#   27: {1: 478, 2: 225, 3: 122, 4: 48, 5: 25, 6: 18, 7: 16, 8: 12},
#   28: {1: 549, 2: 164, 3: 96, 4: 59, 5: 31, 6: 21, 7: 19, 8: 11},
#   29: {1: 511, 2: 210, 3: 144, 4: 122, 5: 63, 6: 44, 7: 37, 8: 27},
#   30: {1: 464, 2: 207, 3: 135, 4: 69, 5: 35, 6: 26, 7: 23, 8: 23},
#   31: {1: 541, 2: 231, 3: 186, 4: 121, 5: 66, 6: 48, 7: 36, 8: 33},
#   32: {1: 599, 2: 261, 3: 174, 4: 110, 5: 62, 6: 50, 7: 39, 8: 38},
#   33: {1: 481, 2: 219, 3: 152, 4: 119, 5: 66, 6: 53, 7: 43, 8: 38},
#   34: {1: 432, 2: 157, 3: 97, 4: 68, 5: 35, 6: 27, 7: 23, 8: 23},
#   35: {1: 465, 2: 128, 3: 88, 4: 59, 5: 35, 6: 24, 7: 18, 8: 16},
#   36: {1: 497, 2: 251, 3: 168, 4: 88, 5: 44, 6: 38, 7: 31, 8: 29},
#   37: {1: 428, 2: 156, 3: 105, 4: 60, 5: 34, 6: 21, 7: 17, 8: 11},
#   38: {1: 498, 2: 273, 3: 176, 4: 121, 5: 71, 6: 43, 7: 33, 8: 31},
#   39: {1: 496, 2: 221, 3: 144, 4: 92, 5: 54, 6: 37, 7: 23, 8: 17},
#   40: {1: 509, 2: 286, 3: 157, 4: 84, 5: 57, 6: 27, 7: 25, 8: 20},
#   41: {1: 452, 2: 164, 3: 100, 4: 76, 5: 45, 6: 27, 7: 21, 8: 20},
#   42: {1: 626, 2: 184, 3: 124, 4: 85, 5: 48, 6: 40, 7: 38, 8: 36},
#   43: {1: 483, 2: 223, 3: 151, 4: 85, 5: 38, 6: 27, 7: 21, 8: 20},
#   44: {1: 460, 2: 201, 3: 135, 4: 98, 5: 61, 6: 48, 7: 33, 8: 28},
#   45: {1: 490, 2: 191, 3: 97, 4: 65, 5: 37, 6: 14, 7: 12, 8: 10},
#   46: {1: 436, 2: 245, 3: 137, 4: 92, 5: 43, 6: 22, 7: 18, 8: 16},
#   47: {1: 479, 2: 225, 3: 126, 4: 74, 5: 28, 6: 19, 7: 11, 8: 9},
#   48: {1: 553, 2: 294, 3: 177, 4: 107, 5: 63, 6: 53, 7: 38, 8: 35},
#   49: {1: 509, 2: 180, 3: 132, 4: 72, 5: 35, 6: 17, 7: 15, 8: 13},
#   50: {1: 468, 2: 170, 3: 84, 4: 43, 5: 15, 6: 13, 7: 13, 8: 10},
#   51: {1: 438, 2: 227, 3: 187, 4: 90, 5: 44, 6: 31, 7: 27, 8: 19},
#   52: {1: 460, 2: 236, 3: 142, 4: 80, 5: 44, 6: 39, 7: 35, 8: 30},
#   53: {1: 449, 2: 176, 3: 113, 4: 60, 5: 27, 6: 16, 7: 13, 8: 12},
#   54: {1: 423, 2: 148, 3: 106, 4: 77, 5: 41, 6: 25, 7: 21, 8: 20},
#   55: {1: 428, 2: 170, 3: 81, 4: 42, 5: 17, 6: 15, 7: 10, 8: 10},
#   56: {1: 544, 2: 196, 3: 103, 4: 56, 5: 31, 6: 18, 7: 15, 8: 13},
#   57: {1: 500, 2: 246, 3: 159, 4: 104, 5: 70, 6: 62, 7: 57, 8: 55},
#   58: {1: 465, 2: 247, 3: 149, 4: 97, 5: 45, 6: 22, 7: 18, 8: 14},
#   59: {1: 575, 2: 205, 3: 112, 4: 81, 5: 27, 6: 19, 7: 18, 8: 17},
#   60: {1: 488, 2: 186, 3: 105, 4: 67, 5: 31, 6: 24, 7: 22, 8: 20},
#   61: {1: 437, 2: 221, 3: 114, 4: 81, 5: 44, 6: 31, 7: 19, 8: 16},
#   62: {1: 441, 2: 187, 3: 121, 4: 69, 5: 38, 6: 36, 7: 28, 8: 27},
#   63: {1: 575, 2: 260, 3: 183, 4: 102, 5: 59, 6: 46, 7: 34, 8: 30},
#   64: {1: 568, 2: 249, 3: 151, 4: 79, 5: 34, 6: 22, 7: 15, 8: 15},
#   65: {1: 545, 2: 184, 3: 107, 4: 52, 5: 30, 6: 14, 7: 9, 8: 9},
#   66: {1: 619, 2: 269, 3: 162, 4: 121, 5: 70, 6: 48, 7: 36, 8: 32},
#   67: {1: 449, 2: 214, 3: 129, 4: 71, 5: 18, 6: 12, 7: 10, 8: 8},
#   68: {1: 485, 2: 266, 3: 151, 4: 97, 5: 50, 6: 30, 7: 24, 8: 23},
#   69: {1: 382, 2: 159, 3: 88, 4: 36, 5: 21, 6: 11, 7: 11, 8: 9},
#   70: {1: 491, 2: 207, 3: 128, 4: 82, 5: 50, 6: 36, 7: 25, 8: 22},
#   71: {1: 525, 2: 164, 3: 108, 4: 81, 5: 44, 6: 32, 7: 27, 8: 26},
#   72: {1: 462, 2: 173, 3: 108, 4: 53, 5: 24, 6: 21, 7: 17, 8: 14},
#   73: {1: 560, 2: 129, 3: 69, 4: 40, 5: 24, 6: 16, 7: 11, 8: 9},
#   74: {1: 532, 2: 333, 3: 193, 4: 100, 5: 63, 6: 38, 7: 18, 8: 12},
#   75: {1: 429, 2: 121, 3: 70, 4: 50, 5: 27, 6: 19, 7: 16, 8: 15},
#   76: {1: 456, 2: 209, 3: 143, 4: 77, 5: 45, 6: 30, 7: 25, 8: 22},
#   77: {1: 600, 2: 210, 3: 100, 4: 79, 5: 43, 6: 28, 7: 21, 8: 19},
#   78: {1: 497, 2: 218, 3: 101, 4: 76, 5: 52, 6: 38, 7: 35, 8: 33},
#   79: {1: 387, 2: 135, 3: 82, 4: 55, 5: 29, 6: 16, 7: 12, 8: 11},
#   80: {1: 487, 2: 247, 3: 131, 4: 53, 5: 27, 6: 22, 7: 16, 8: 15},
#   81: {1: 559, 2: 298, 3: 201, 4: 105, 5: 62, 6: 48, 7: 41, 8: 37},
#   82: {1: 502, 2: 297, 3: 200, 4: 131, 5: 73, 6: 52, 7: 36, 8: 32},
#   83: {1: 399, 2: 169, 3: 119, 4: 76, 5: 38, 6: 26, 7: 22, 8: 19},
#   84: {1: 495, 2: 191, 3: 120, 4: 66, 5: 17, 6: 14, 7: 12, 8: 9},
#   85: {1: 450, 2: 156, 3: 82, 4: 46, 5: 30, 6: 23, 7: 22, 8: 22},
#   86: {1: 385, 2: 136, 3: 82, 4: 51, 5: 30, 6: 22, 7: 18, 8: 16},
#   87: {1: 471, 2: 201, 3: 100, 4: 73, 5: 57, 6: 48, 7: 23, 8: 21},
#   88: {1: 410, 2: 174, 3: 95, 4: 59, 5: 30, 6: 25, 7: 24, 8: 21},
#   89: {1: 353, 2: 139, 3: 86, 4: 40, 5: 17, 6: 13, 7: 10, 8: 10},
#   90: {1: 356, 2: 152, 3: 94, 4: 40, 5: 25, 6: 13, 7: 11, 8: 10},
#   91: {1: 463, 2: 229, 3: 135, 4: 89, 5: 50, 6: 31, 7: 18, 8: 18},
#   92: {1: 569, 2: 238, 3: 155, 4: 92, 5: 50, 6: 39, 7: 20, 8: 18},
#   93: {1: 448, 2: 167, 3: 85, 4: 52, 5: 35, 6: 28, 7: 22, 8: 21},
#   94: {1: 470, 2: 230, 3: 111, 4: 65, 5: 28, 6: 14, 7: 7, 8: 6},
#   95: {1: 441, 2: 186, 3: 135, 4: 94, 5: 29, 6: 19, 7: 18, 8: 18},
#   96: {1: 502, 2: 204, 3: 130, 4: 69, 5: 35, 6: 21, 7: 15, 8: 14},
#   97: {1: 527, 2: 162, 3: 88, 4: 59, 5: 35, 6: 21, 7: 20, 8: 20},
#   98: {1: 572, 2: 268, 3: 171, 4: 108, 5: 59, 6: 40, 7: 35, 8: 30},
#   99: {1: 530, 2: 252, 3: 198, 4: 135, 5: 75, 6: 51, 7: 43, 8: 38},
#   100: {1: 542, 2: 155, 3: 90, 4: 64, 5: 42, 6: 40, 7: 31, 8: 30},
#   101: {1: 481, 2: 182, 3: 109, 4: 48, 5: 24, 6: 15, 7: 14, 8: 13},
#   102: {1: 417, 2: 179, 3: 99, 4: 62, 5: 36, 6: 23, 7: 13, 8: 10},
#   103: {1: 516, 2: 204, 3: 125, 4: 69, 5: 36, 6: 26, 7: 19, 8: 19},
#   104: {1: 464, 2: 210, 3: 117, 4: 66, 5: 37, 6: 19, 7: 14, 8: 13},
#   105: {1: 462, 2: 210, 3: 133, 4: 80, 5: 25, 6: 15, 7: 12, 8: 11},
#   106: {1: 436, 2: 180, 3: 93, 4: 49, 5: 30, 6: 23, 7: 22, 8: 18},
#   107: {1: 444, 2: 128, 3: 76, 4: 44, 5: 24, 6: 15, 7: 13, 8: 12},
#   108: {1: 453, 2: 207, 3: 140, 4: 82, 5: 49, 6: 38, 7: 27, 8: 24},
#   109: {1: 360, 2: 109, 3: 70, 4: 43, 5: 23, 6: 20, 7: 14, 8: 13},
#   110: {1: 547, 2: 285, 3: 179, 4: 110, 5: 55, 6: 38, 7: 34, 8: 32},
#   111: {1: 436, 2: 200, 3: 139, 4: 84, 5: 53, 6: 30, 7: 28, 8: 23},
#   112: {1: 524, 2: 231, 3: 139, 4: 88, 5: 52, 6: 34, 7: 24, 8: 16},
#   113: {1: 469, 2: 141, 3: 93, 4: 50, 5: 28, 6: 18, 7: 16, 8: 14},
#   114: {1: 490, 2: 142, 3: 84, 4: 49, 5: 22, 6: 16, 7: 12, 8: 10},
#   115: {1: 504, 2: 243, 3: 162, 4: 100, 5: 60, 6: 43, 7: 33, 8: 30},
#   116: {1: 396, 2: 132, 3: 101, 4: 66, 5: 43, 6: 28, 7: 23, 8: 22},
#   117: {1: 558, 2: 234, 3: 140, 4: 79, 5: 47, 6: 33, 7: 27, 8: 25},
#   118: {1: 500, 2: 199, 3: 129, 4: 74, 5: 45, 6: 18, 7: 18, 8: 15},
#   119: {1: 387, 2: 140, 3: 89, 4: 64, 5: 26, 6: 20, 7: 16, 8: 16},
#   120: {1: 420, 2: 216, 3: 154, 4: 87, 5: 41, 6: 35, 7: 31, 8: 30},
#   121: {1: 507, 2: 244, 3: 163, 4: 106, 5: 60, 6: 41, 7: 38, 8: 32},
#   122: {1: 488, 2: 177, 3: 115, 4: 92, 5: 49, 6: 39, 7: 22, 8: 19},
#   123: {1: 460, 2: 160, 3: 115, 4: 73, 5: 52, 6: 25, 7: 24, 8: 23},
#   124: {1: 517, 2: 237, 3: 139, 4: 95, 5: 52, 6: 36, 7: 30, 8: 27},
#   125: {1: 511, 2: 214, 3: 163, 4: 88, 5: 57, 6: 34, 7: 31, 8: 29},
#   126: {1: 488, 2: 178, 3: 129, 4: 58, 5: 29, 6: 19, 7: 14, 8: 13},
#   127: {1: 394, 2: 192, 3: 107, 4: 66, 5: 32, 6: 17, 7: 12, 8: 11},
#   128: {1: 484, 2: 142, 3: 90, 4: 51, 5: 34, 6: 24, 7: 22, 8: 19},
#   129: {1: 545, 2: 247, 3: 166, 4: 93, 5: 70, 6: 60, 7: 45, 8: 40},
#   130: {1: 480, 2: 139, 3: 92, 4: 43, 5: 27, 6: 23, 7: 18, 8: 18},
#   131: {1: 436, 2: 118, 3: 70, 4: 39, 5: 25, 6: 15, 7: 12, 8: 11},
#   132: {1: 489, 2: 192, 3: 120, 4: 84, 5: 37, 6: 30, 7: 26, 8: 23},
#   133: {1: 523, 2: 268, 3: 162, 4: 94, 5: 45, 6: 21, 7: 11, 8: 7},
#   134: {1: 440, 2: 183, 3: 130, 4: 83, 5: 37, 6: 34, 7: 21, 8: 16},
#   135: {1: 454, 2: 212, 3: 156, 4: 106, 5: 58, 6: 41, 7: 28, 8: 25},
#   136: {1: 471, 2: 245, 3: 122, 4: 64, 5: 36, 6: 29, 7: 24, 8: 19},
#   137: {1: 466, 2: 166, 3: 89, 4: 56, 5: 40, 6: 32, 7: 19, 8: 16},
#   138: {1: 401, 2: 161, 3: 110, 4: 62, 5: 32, 6: 20, 7: 9, 8: 7},
#   139: {1: 577, 2: 188, 3: 108, 4: 65, 5: 45, 6: 33, 7: 33, 8: 33},
#   140: {1: 486, 2: 126, 3: 73, 4: 48, 5: 19, 6: 13, 7: 11, 8: 11},
#   141: {1: 462, 2: 172, 3: 102, 4: 67, 5: 44, 6: 38, 7: 25, 8: 22},
#   142: {1: 482, 2: 188, 3: 124, 4: 72, 5: 34, 6: 17, 7: 12, 8: 11},
#   143: {1: 405, 2: 141, 3: 85, 4: 43, 5: 10, 6: 8, 7: 6, 8: 5},
#   144: {1: 411, 2: 205, 3: 129, 4: 60, 5: 34, 6: 23, 7: 18, 8: 17},
#   145: {1: 477, 2: 245, 3: 151, 4: 69, 5: 40, 6: 26, 7: 16, 8: 16},
#   146: {1: 641, 2: 387, 3: 252, 4: 154, 5: 105, 6: 81, 7: 69, 8: 67},
#   147: {1: 555, 2: 171, 3: 85, 4: 49, 5: 33, 6: 26, 7: 21, 8: 20},
#   148: {1: 394, 2: 144, 3: 79, 4: 58, 5: 36, 6: 26, 7: 26, 8: 25},
#   149: {1: 449, 2: 222, 3: 149, 4: 71, 5: 45, 6: 38, 7: 34, 8: 31},
#   150: {1: 393, 2: 136, 3: 87, 4: 48, 5: 27, 6: 16, 7: 10, 8: 9},
#   151: {1: 386, 2: 97, 3: 46, 4: 29, 5: 10, 6: 9, 7: 8, 8: 8},
#   152: {1: 502, 2: 271, 3: 165, 4: 90, 5: 54, 6: 49, 7: 32, 8: 29},
#   153: {1: 451, 2: 162, 3: 104, 4: 80, 5: 45, 6: 22, 7: 15, 8: 14},
#   154: {1: 457, 2: 144, 3: 75, 4: 59, 5: 34, 6: 27, 7: 21, 8: 14},
#   155: {1: 473, 2: 143, 3: 83, 4: 56, 5: 21, 6: 16, 7: 12, 8: 11},
#   156: {1: 515, 2: 161, 3: 103, 4: 65, 5: 38, 6: 25, 7: 23, 8: 21},
#   157: {1: 408, 2: 138, 3: 104, 4: 71, 5: 49, 6: 40, 7: 25, 8: 24},
#   158: {1: 429, 2: 144, 3: 94, 4: 59, 5: 47, 6: 34, 7: 23, 8: 21},
#   159: {1: 430, 2: 147, 3: 89, 4: 64, 5: 21, 6: 12, 7: 9, 8: 9},
#   160: {1: 538, 2: 261, 3: 158, 4: 74, 5: 44, 6: 30, 7: 24, 8: 24},
#   161: {1: 540, 2: 192, 3: 125, 4: 82, 5: 48, 6: 41, 7: 31, 8: 30},
#   162: {1: 405, 2: 164, 3: 108, 4: 71, 5: 41, 6: 30, 7: 26, 8: 26},
#   163: {1: 541, 2: 280, 3: 186, 4: 131, 5: 66, 6: 45, 7: 31, 8: 27},
#   164: {1: 522, 2: 223, 3: 117, 4: 47, 5: 21, 6: 12, 7: 9, 8: 7},
#   165: {1: 432, 2: 135, 3: 80, 4: 53, 5: 38, 6: 24, 7: 19, 8: 17},
#   166: {1: 482, 2: 155, 3: 110, 4: 65, 5: 32, 6: 18, 7: 18, 8: 17},
#   167: {1: 427, 2: 150, 3: 80, 4: 49, 5: 36, 6: 14, 7: 10, 8: 9},
#   168: {1: 528, 2: 203, 3: 114, 4: 54, 5: 34, 6: 19, 7: 13, 8: 12},
#   169: {1: 426, 2: 138, 3: 74, 4: 48, 5: 27, 6: 19, 7: 14, 8: 11},
#   170: {1: 457, 2: 222, 3: 130, 4: 82, 5: 45, 6: 37, 7: 26, 8: 23},
#   171: {1: 450, 2: 197, 3: 132, 4: 58, 5: 24, 6: 14, 7: 8, 8: 8},
#   172: {1: 512, 2: 297, 3: 210, 4: 155, 5: 88, 6: 71, 7: 55, 8: 49},
#   173: {1: 397, 2: 179, 3: 112, 4: 78, 5: 43, 6: 40, 7: 37, 8: 36},
#   174: {1: 461, 2: 157, 3: 82, 4: 59, 5: 40, 6: 22, 7: 18, 8: 18},
#   175: {1: 414, 2: 129, 3: 83, 4: 58, 5: 34, 6: 19, 7: 18, 8: 17},
#   176: {1: 562, 2: 189, 3: 106, 4: 80, 5: 48, 6: 27, 7: 14, 8: 12},
#   177: {1: 525, 2: 320, 3: 202, 4: 84, 5: 37, 6: 16, 7: 12, 8: 11},
#   178: {1: 439, 2: 169, 3: 135, 4: 97, 5: 41, 6: 32, 7: 26, 8: 25},
#   179: {1: 529, 2: 185, 3: 90, 4: 56, 5: 34, 6: 19, 7: 12, 8: 11},
#   180: {1: 438, 2: 224, 3: 122, 4: 62, 5: 52, 6: 30, 7: 19, 8: 16},
#   181: {1: 559, 2: 317, 3: 157, 4: 103, 5: 53, 6: 38, 7: 27, 8: 22},
#   182: {1: 383, 2: 130, 3: 88, 4: 61, 5: 26, 6: 13, 7: 8, 8: 8},
#   183: {1: 502, 2: 198, 3: 112, 4: 62, 5: 35, 6: 25, 7: 23, 8: 18},
#   184: {1: 436, 2: 188, 3: 107, 4: 63, 5: 28, 6: 18, 7: 12, 8: 12},
#   185: {1: 492, 2: 281, 3: 164, 4: 110, 5: 73, 6: 58, 7: 40, 8: 38},
#   186: {1: 442, 2: 227, 3: 142, 4: 106, 5: 72, 6: 46, 7: 41, 8: 32},
#   187: {1: 432, 2: 98, 3: 53, 4: 32, 5: 16, 6: 13, 7: 13, 8: 10},
#   188: {1: 451, 2: 143, 3: 102, 4: 58, 5: 33, 6: 22, 7: 19, 8: 18},
#   189: {1: 455, 2: 152, 3: 95, 4: 51, 5: 30, 6: 28, 7: 22, 8: 19},
#   190: {1: 519, 2: 263, 3: 137, 4: 65, 5: 30, 6: 21, 7: 14, 8: 13},
#   191: {1: 449, 2: 147, 3: 96, 4: 45, 5: 30, 6: 19, 7: 13, 8: 11},
#   192: {1: 527, 2: 264, 3: 165, 4: 121, 5: 54, 6: 39, 7: 33, 8: 28},
#   193: {1: 481, 2: 178, 3: 120, 4: 94, 5: 55, 6: 27, 7: 24, 8: 22},
#   194: {1: 477, 2: 192, 3: 103, 4: 59, 5: 37, 6: 37, 7: 36, 8: 34},
#   195: {1: 462, 2: 211, 3: 107, 4: 68, 5: 44, 6: 33, 7: 29, 8: 27},
#   196: {1: 441, 2: 153, 3: 71, 4: 39, 5: 20, 6: 13, 7: 8, 8: 7},
#   197: {1: 497, 2: 200, 3: 128, 4: 88, 5: 61, 6: 41, 7: 32, 8: 28},
#   198: {1: 481, 2: 172, 3: 105, 4: 58, 5: 33, 6: 21, 7: 17, 8: 14},
#   199: {1: 394, 2: 139, 3: 77, 4: 51, 5: 31, 6: 29, 7: 27, 8: 24},
#   200: {1: 496, 2: 210, 3: 102, 4: 70, 5: 41, 6: 24, 7: 18, 8: 16},
#   201: {1: 576, 2: 203, 3: 123, 4: 68, 5: 39, 6: 29, 7: 19, 8: 18},
#   202: {1: 571, 2: 154, 3: 113, 4: 66, 5: 40, 6: 29, 7: 17, 8: 14},
#   203: {1: 501, 2: 185, 3: 125, 4: 77, 5: 42, 6: 35, 7: 24, 8: 24},
#   204: {1: 474, 2: 146, 3: 75, 4: 43, 5: 22, 6: 10, 7: 9, 8: 9},
#   205: {1: 478, 2: 184, 3: 103, 4: 58, 5: 26, 6: 17, 7: 15, 8: 15},
#   206: {1: 406, 2: 102, 3: 54, 4: 35, 5: 14, 6: 11, 7: 9, 8: 9},
#   207: {1: 392, 2: 148, 3: 86, 4: 66, 5: 36, 6: 26, 7: 22, 8: 19},
#   208: {1: 539, 2: 259, 3: 128, 4: 86, 5: 46, 6: 29, 7: 25, 8: 25},
#   209: {1: 445, 2: 175, 3: 127, 4: 86, 5: 30, 6: 21, 7: 17, 8: 13},
#   210: {1: 474, 2: 169, 3: 146, 4: 107, 5: 53, 6: 41, 7: 30, 8: 24},
#   211: {1: 476, 2: 166, 3: 99, 4: 63, 5: 46, 6: 31, 7: 23, 8: 22},
#   212: {1: 437, 2: 211, 3: 151, 4: 90, 5: 43, 6: 32, 7: 29, 8: 27},
#   213: {1: 322, 2: 153, 3: 85, 4: 55, 5: 29, 6: 26, 7: 15, 8: 15},
#   214: {1: 377, 2: 145, 3: 87, 4: 50, 5: 31, 6: 19, 7: 16, 8: 14},
#   215: {1: 556, 2: 187, 3: 112, 4: 45, 5: 21, 6: 19, 7: 13, 8: 12},
#   216: {1: 563, 2: 271, 3: 169, 4: 96, 5: 45, 6: 26, 7: 21, 8: 20},
#   217: {1: 464, 2: 239, 3: 128, 4: 91, 5: 56, 6: 50, 7: 42, 8: 35},
#   218: {1: 472, 2: 178, 3: 110, 4: 58, 5: 40, 6: 19, 7: 14, 8: 14},
#   219: {1: 501, 2: 207, 3: 134, 4: 64, 5: 35, 6: 17, 7: 14, 8: 13},
#   220: {1: 463, 2: 247, 3: 125, 4: 88, 5: 65, 6: 49, 7: 33, 8: 28},
#   221: {1: 537, 2: 160, 3: 87, 4: 56, 5: 29, 6: 21, 7: 21, 8: 20},
#   222: {1: 561, 2: 230, 3: 131, 4: 80, 5: 38, 6: 21, 7: 16, 8: 15},
#   223: {1: 549, 2: 247, 3: 144, 4: 108, 5: 51, 6: 32, 7: 30, 8: 29},
#   224: {1: 508, 2: 212, 3: 130, 4: 72, 5: 52, 6: 34, 7: 21, 8: 21},
#   225: {1: 585, 2: 175, 3: 99, 4: 54, 5: 35, 6: 21, 7: 17, 8: 15},
#   226: {1: 583, 2: 152, 3: 92, 4: 44, 5: 20, 6: 15, 7: 11, 8: 11},
#   227: {1: 486, 2: 200, 3: 108, 4: 71, 5: 30, 6: 16, 7: 13, 8: 13},
#   228: {1: 535, 2: 251, 3: 147, 4: 77, 5: 49, 6: 29, 7: 26, 8: 23},
#   229: {1: 481, 2: 200, 3: 105, 4: 78, 5: 48, 6: 35, 7: 18, 8: 18},
#   230: {1: 553, 2: 292, 3: 172, 4: 80, 5: 48, 6: 26, 7: 18, 8: 17},
#   231: {1: 534, 2: 198, 3: 134, 4: 81, 5: 59, 6: 39, 7: 29, 8: 23},
#   232: {1: 503, 2: 249, 3: 145, 4: 89, 5: 45, 6: 43, 7: 34, 8: 30},
#   233: {1: 515, 2: 176, 3: 102, 4: 51, 5: 36, 6: 29, 7: 19, 8: 18},
#   234: {1: 491, 2: 178, 3: 113, 4: 86, 5: 25, 6: 13, 7: 7, 8: 7},
#   235: {1: 492, 2: 247, 3: 133, 4: 90, 5: 61, 6: 53, 7: 36, 8: 33},
#   236: {1: 502, 2: 186, 3: 125, 4: 81, 5: 48, 6: 28, 7: 26, 8: 26},
#   237: {1: 424, 2: 114, 3: 59, 4: 43, 5: 25, 6: 21, 7: 17, 8: 15},
#   238: {1: 631, 2: 238, 3: 149, 4: 84, 5: 48, 6: 40, 7: 28, 8: 27},
#   239: {1: 406, 2: 193, 3: 106, 4: 52, 5: 31, 6: 15, 7: 12, 8: 9},
#   240: {1: 532, 2: 265, 3: 145, 4: 66, 5: 34, 6: 30, 7: 20, 8: 17},
#   241: {1: 549, 2: 174, 3: 113, 4: 83, 5: 53, 6: 45, 7: 39, 8: 35},
#   242: {1: 447, 2: 250, 3: 141, 4: 85, 5: 41, 6: 28, 7: 24, 8: 22},
#   243: {1: 465, 2: 167, 3: 121, 4: 87, 5: 50, 6: 38, 7: 34, 8: 29},
#   244: {1: 514, 2: 146, 3: 99, 4: 64, 5: 34, 6: 22, 7: 11, 8: 11},
#   245: {1: 412, 2: 214, 3: 143, 4: 82, 5: 45, 6: 29, 7: 17, 8: 14},
#   246: {1: 370, 2: 161, 3: 92, 4: 45, 5: 25, 6: 15, 7: 8, 8: 7},
#   247: {1: 435, 2: 161, 3: 107, 4: 68, 5: 36, 6: 30, 7: 26, 8: 24},
#   248: {1: 437, 2: 192, 3: 124, 4: 74, 5: 43, 6: 30, 7: 24, 8: 21},
#   249: {1: 510, 2: 204, 3: 128, 4: 72, 5: 42, 6: 26, 7: 13, 8: 11},
#   250: {1: 477, 2: 164, 3: 124, 4: 83, 5: 50, 6: 45, 7: 42, 8: 33},
#   251: {1: 523, 2: 295, 3: 185, 4: 128, 5: 63, 6: 50, 7: 39, 8: 35},
#   252: {1: 436, 2: 139, 3: 81, 4: 56, 5: 30, 6: 14, 7: 8, 8: 7},
#   253: {1: 496, 2: 132, 3: 50, 4: 36, 5: 14, 6: 7, 7: 7, 8: 7},
#   254: {1: 381, 2: 157, 3: 92, 4: 64, 5: 40, 6: 32, 7: 28, 8: 26},
#   255: {1: 434, 2: 195, 3: 96, 4: 71, 5: 44, 6: 24, 7: 19, 8: 18},
#   256: {1: 536, 2: 248, 3: 135, 4: 86, 5: 43, 6: 30, 7: 18, 8: 17},
#   257: {1: 426, 2: 183, 3: 122, 4: 65, 5: 34, 6: 29, 7: 26, 8: 24},
#   258: {1: 555, 2: 166, 3: 97, 4: 65, 5: 36, 6: 26, 7: 21, 8: 19},
#   259: {1: 448, 2: 196, 3: 120, 4: 73, 5: 36, 6: 30, 7: 21, 8: 18},
#   260: {1: 487, 2: 126, 3: 70, 4: 42, 5: 19, 6: 15, 7: 12, 8: 11},
#   261: {1: 482, 2: 209, 3: 143, 4: 86, 5: 36, 6: 24, 7: 19, 8: 16},
#   262: {1: 476, 2: 195, 3: 99, 4: 68, 5: 30, 6: 23, 7: 20, 8: 18},
#   263: {1: 509, 2: 250, 3: 178, 4: 97, 5: 54, 6: 35, 7: 29, 8: 25},
#   264: {1: 555, 2: 194, 3: 120, 4: 83, 5: 48, 6: 36, 7: 35, 8: 30},
#   265: {1: 570, 2: 255, 3: 186, 4: 142, 5: 63, 6: 38, 7: 33, 8: 29},
#   266: {1: 485, 2: 167, 3: 99, 4: 52, 5: 20, 6: 15, 7: 13, 8: 12},
#   267: {1: 410, 2: 208, 3: 113, 4: 55, 5: 25, 6: 20, 7: 15, 8: 13},
#   268: {1: 466, 2: 172, 3: 114, 4: 80, 5: 41, 6: 26, 7: 19, 8: 18},
#   269: {1: 523, 2: 287, 3: 178, 4: 112, 5: 67, 6: 65, 7: 46, 8: 41},
#   270: {1: 423, 2: 184, 3: 95, 4: 44, 5: 23, 6: 13, 7: 9, 8: 7},
#   271: {1: 510, 2: 210, 3: 108, 4: 65, 5: 29, 6: 25, 7: 22, 8: 21},
#   272: {1: 653, 2: 354, 3: 168, 4: 102, 5: 55, 6: 38, 7: 28, 8: 27},
#   273: {1: 458, 2: 152, 3: 101, 4: 61, 5: 40, 6: 19, 7: 16, 8: 15},
#   274: {1: 523, 2: 199, 3: 95, 4: 59, 5: 31, 6: 16, 7: 14, 8: 11},
#   275: {1: 453, 2: 223, 3: 97, 4: 52, 5: 30, 6: 22, 7: 14, 8: 13},
#   276: {1: 335, 2: 183, 3: 122, 4: 69, 5: 28, 6: 24, 7: 18, 8: 17},
#   277: {1: 538, 2: 214, 3: 120, 4: 81, 5: 48, 6: 26, 7: 18, 8: 16},
#   278: {1: 507, 2: 255, 3: 178, 4: 122, 5: 77, 6: 55, 7: 52, 8: 42},
#   279: {1: 518, 2: 188, 3: 106, 4: 53, 5: 30, 6: 22, 7: 20, 8: 20},
#   280: {1: 582, 2: 271, 3: 185, 4: 131, 5: 69, 6: 44, 7: 33, 8: 31},
#   281: {1: 537, 2: 282, 3: 177, 4: 90, 5: 39, 6: 21, 7: 17, 8: 16},
#   282: {1: 509, 2: 233, 3: 144, 4: 82, 5: 43, 6: 23, 7: 18, 8: 17},
#   283: {1: 520, 2: 268, 3: 154, 4: 87, 5: 48, 6: 32, 7: 22, 8: 17},
#   284: {1: 464, 2: 203, 3: 121, 4: 85, 5: 51, 6: 41, 7: 25, 8: 24},
#   285: {1: 459, 2: 231, 3: 127, 4: 94, 5: 53, 6: 24, 7: 13, 8: 13},
#   286: {1: 525, 2: 244, 3: 155, 4: 128, 5: 71, 6: 48, 7: 37, 8: 34},
#   287: {1: 393, 2: 161, 3: 81, 4: 46, 5: 25, 6: 15, 7: 6, 8: 4},
#   288: {1: 483, 2: 194, 3: 106, 4: 53, 5: 27, 6: 13, 7: 10, 8: 9},
#   289: {1: 597, 2: 338, 3: 181, 4: 103, 5: 67, 6: 51, 7: 43, 8: 36},
#   290: {1: 472, 2: 192, 3: 119, 4: 67, 5: 39, 6: 19, 7: 14, 8: 14},
#   291: {1: 406, 2: 175, 3: 121, 4: 77, 5: 46, 6: 25, 7: 19, 8: 18},
#   292: {1: 499, 2: 160, 3: 105, 4: 65, 5: 27, 6: 21, 7: 17, 8: 16},
#   293: {1: 545, 2: 260, 3: 128, 4: 96, 5: 66, 6: 39, 7: 32, 8: 28},
#   294: {1: 447, 2: 208, 3: 132, 4: 66, 5: 30, 6: 25, 7: 21, 8: 17},
#   295: {1: 450, 2: 173, 3: 116, 4: 79, 5: 31, 6: 21, 7: 10, 8: 9},
#   296: {1: 452, 2: 188, 3: 123, 4: 58, 5: 40, 6: 30, 7: 23, 8: 23},
#   297: {1: 486, 2: 182, 3: 90, 4: 45, 5: 27, 6: 15, 7: 13, 8: 13},
#   298: {1: 503, 2: 206, 3: 144, 4: 79, 5: 56, 6: 26, 7: 15, 8: 13},
#   299: {1: 508, 2: 209, 3: 132, 4: 73, 5: 43, 6: 26, 7: 22, 8: 22},
#   300: {1: 515, 2: 188, 3: 96, 4: 67, 5: 40, 6: 18, 7: 14, 8: 12},
#   301: {1: 423, 2: 203, 3: 150, 4: 107, 5: 83, 6: 65, 7: 56, 8: 47},
#   302: {1: 486, 2: 207, 3: 137, 4: 82, 5: 44, 6: 33, 7: 13, 8: 11},
#   303: {1: 383, 2: 173, 3: 86, 4: 55, 5: 29, 6: 22, 7: 19, 8: 14},
#   304: {1: 515, 2: 172, 3: 111, 4: 84, 5: 41, 6: 29, 7: 25, 8: 23},
#   305: {1: 470, 2: 248, 3: 129, 4: 79, 5: 48, 6: 33, 7: 26, 8: 25},
#   306: {1: 536, 2: 266, 3: 126, 4: 75, 5: 56, 6: 38, 7: 32, 8: 30},
#   307: {1: 481, 2: 208, 3: 125, 4: 92, 5: 55, 6: 35, 7: 25, 8: 25},
#   308: {1: 486, 2: 209, 3: 129, 4: 63, 5: 34, 6: 26, 7: 22, 8: 19},
#   309: {1: 449, 2: 165, 3: 99, 4: 60, 5: 40, 6: 33, 7: 25, 8: 25},
#   310: {1: 523, 2: 248, 3: 144, 4: 87, 5: 45, 6: 26, 7: 19, 8: 17},
#   311: {1: 463, 2: 203, 3: 115, 4: 63, 5: 37, 6: 22, 7: 18, 8: 13},
#   312: {1: 540, 2: 217, 3: 144, 4: 99, 5: 65, 6: 37, 7: 30, 8: 26},
#   313: {1: 423, 2: 185, 3: 100, 4: 79, 5: 52, 6: 32, 7: 14, 8: 10},
#   314: {1: 452, 2: 191, 3: 111, 4: 62, 5: 31, 6: 25, 7: 19, 8: 15},
#   315: {1: 485, 2: 231, 3: 143, 4: 80, 5: 44, 6: 38, 7: 26, 8: 24},
#   316: {1: 480, 2: 228, 3: 172, 4: 102, 5: 50, 6: 36, 7: 27, 8: 25},
#   317: {1: 407, 2: 127, 3: 67, 4: 46, 5: 16, 6: 13, 7: 9, 8: 9},
#   318: {1: 482, 2: 172, 3: 73, 4: 51, 5: 28, 6: 22, 7: 18, 8: 16},
#   319: {1: 482, 2: 252, 3: 159, 4: 114, 5: 72, 6: 45, 7: 43, 8: 37},
#   320: {1: 482, 2: 267, 3: 187, 4: 88, 5: 48, 6: 34, 7: 31, 8: 28},
#   321: {1: 351, 2: 112, 3: 67, 4: 49, 5: 22, 6: 17, 7: 17, 8: 13},
#   322: {1: 493, 2: 202, 3: 104, 4: 66, 5: 41, 6: 26, 7: 21, 8: 18},
#   323: {1: 526, 2: 288, 3: 188, 4: 111, 5: 70, 6: 56, 7: 42, 8: 35},
#   324: {1: 446, 2: 186, 3: 117, 4: 74, 5: 42, 6: 26, 7: 23, 8: 19},
#   325: {1: 454, 2: 126, 3: 78, 4: 53, 5: 26, 6: 21, 7: 18, 8: 16},
#   326: {1: 411, 2: 143, 3: 84, 4: 46, 5: 29, 6: 11, 7: 9, 8: 8},
#   327: {1: 514, 2: 219, 3: 134, 4: 72, 5: 38, 6: 25, 7: 22, 8: 21},
#   328: {1: 503, 2: 198, 3: 100, 4: 54, 5: 28, 6: 18, 7: 12, 8: 9},
#   329: {1: 526, 2: 255, 3: 174, 4: 106, 5: 64, 6: 35, 7: 19, 8: 19},
#   330: {1: 535, 2: 191, 3: 122, 4: 76, 5: 42, 6: 28, 7: 25, 8: 24},
#   331: {1: 483, 2: 243, 3: 147, 4: 88, 5: 55, 6: 22, 7: 22, 8: 20},
#   332: {1: 553, 2: 298, 3: 192, 4: 146, 5: 88, 6: 71, 7: 54, 8: 52},
#   333: {1: 347, 2: 133, 3: 96, 4: 56, 5: 31, 6: 21, 7: 19, 8: 15},
#   334: {1: 571, 2: 198, 3: 111, 4: 79, 5: 51, 6: 28, 7: 20, 8: 19},
#   335: {1: 495, 2: 182, 3: 87, 4: 41, 5: 25, 6: 19, 7: 14, 8: 14},
#   336: {1: 512, 2: 263, 3: 162, 4: 110, 5: 56, 6: 37, 7: 25, 8: 23},
#   337: {1: 495, 2: 170, 3: 108, 4: 67, 5: 46, 6: 30, 7: 28, 8: 28},
#   338: {1: 484, 2: 214, 3: 104, 4: 56, 5: 30, 6: 21, 7: 19, 8: 19},
#   339: {1: 570, 2: 260, 3: 141, 4: 93, 5: 37, 6: 16, 7: 10, 8: 10},
#   340: {1: 559, 2: 226, 3: 151, 4: 66, 5: 39, 6: 19, 7: 15, 8: 14},
#   341: {1: 530, 2: 187, 3: 84, 4: 42, 5: 18, 6: 12, 7: 11, 8: 11},
#   342: {1: 545, 2: 236, 3: 155, 4: 97, 5: 60, 6: 38, 7: 33, 8: 32},
#   343: {1: 467, 2: 175, 3: 120, 4: 87, 5: 42, 6: 32, 7: 21, 8: 14},
#   344: {1: 397, 2: 152, 3: 98, 4: 64, 5: 33, 6: 15, 7: 14, 8: 12},
#   345: {1: 499, 2: 165, 3: 100, 4: 62, 5: 33, 6: 12, 7: 12, 8: 11},
#   346: {1: 508, 2: 222, 3: 117, 4: 71, 5: 29, 6: 20, 7: 19, 8: 19},
#   347: {1: 409, 2: 177, 3: 97, 4: 59, 5: 33, 6: 13, 7: 9, 8: 9},
#   348: {1: 498, 2: 201, 3: 131, 4: 74, 5: 40, 6: 24, 7: 21, 8: 20},
#   349: {1: 482, 2: 227, 3: 146, 4: 102, 5: 58, 6: 50, 7: 29, 8: 28},
#   350: {1: 458, 2: 200, 3: 134, 4: 84, 5: 38, 6: 27, 7: 26, 8: 25},
#   351: {1: 500, 2: 242, 3: 153, 4: 74, 5: 41, 6: 26, 7: 20, 8: 20},
#   352: {1: 497, 2: 264, 3: 127, 4: 72, 5: 52, 6: 37, 7: 37, 8: 35},
#   353: {1: 593, 2: 266, 3: 170, 4: 77, 5: 45, 6: 37, 7: 35, 8: 31},
#   354: {1: 410, 2: 149, 3: 95, 4: 46, 5: 28, 6: 24, 7: 16, 8: 15},
#   355: {1: 469, 2: 219, 3: 115, 4: 81, 5: 45, 6: 30, 7: 23, 8: 19},
#   356: {1: 514, 2: 233, 3: 143, 4: 95, 5: 49, 6: 28, 7: 19, 8: 18},
#   357: {1: 517, 2: 226, 3: 146, 4: 105, 5: 47, 6: 29, 7: 22, 8: 22},
#   358: {1: 416, 2: 185, 3: 109, 4: 77, 5: 47, 6: 26, 7: 24, 8: 23},
#   359: {1: 444, 2: 228, 3: 140, 4: 90, 5: 38, 6: 29, 7: 22, 8: 21},
#   360: {1: 443, 2: 155, 3: 91, 4: 58, 5: 34, 6: 25, 7: 18, 8: 17},
#   361: {1: 530, 2: 243, 3: 141, 4: 79, 5: 45, 6: 33, 7: 25, 8: 19},
#   362: {1: 512, 2: 170, 3: 107, 4: 74, 5: 49, 6: 36, 7: 30, 8: 26},
#   363: {1: 513, 2: 220, 3: 154, 4: 99, 5: 63, 6: 49, 7: 35, 8: 28},
#   364: {1: 556, 2: 190, 3: 130, 4: 102, 5: 61, 6: 36, 7: 33, 8: 28},
#   365: {1: 424, 2: 116, 3: 63, 4: 48, 5: 26, 6: 12, 7: 11, 8: 7},
#   366: {1: 624, 2: 281, 3: 159, 4: 66, 5: 38, 6: 23, 7: 20, 8: 17},
#   367: {1: 542, 2: 269, 3: 129, 4: 87, 5: 45, 6: 37, 7: 25, 8: 25},
#   368: {1: 491, 2: 215, 3: 153, 4: 92, 5: 57, 6: 45, 7: 40, 8: 33},
#   369: {1: 478, 2: 196, 3: 136, 4: 90, 5: 38, 6: 26, 7: 16, 8: 14},
#   370: {1: 440, 2: 164, 3: 109, 4: 78, 5: 41, 6: 29, 7: 24, 8: 23},
#   371: {1: 472, 2: 202, 3: 112, 4: 65, 5: 35, 6: 25, 7: 25, 8: 24},
#   372: {1: 511, 2: 203, 3: 100, 4: 74, 5: 47, 6: 24, 7: 19, 8: 17},
#   373: {1: 451, 2: 202, 3: 107, 4: 38, 5: 16, 6: 11, 7: 9, 8: 8},
#   374: {1: 576, 2: 312, 3: 228, 4: 174, 5: 99, 6: 50, 7: 44, 8: 38},
#   375: {1: 579, 2: 221, 3: 127, 4: 75, 5: 34, 6: 24, 7: 19, 8: 17},
#   376: {1: 426, 2: 187, 3: 104, 4: 68, 5: 39, 6: 25, 7: 19, 8: 17},
#   377: {1: 487, 2: 188, 3: 103, 4: 65, 5: 33, 6: 17, 7: 8, 8: 8},
#   378: {1: 430, 2: 168, 3: 75, 4: 40, 5: 19, 6: 10, 7: 7, 8: 6},
#   379: {1: 490, 2: 241, 3: 133, 4: 91, 5: 37, 6: 32, 7: 25, 8: 25},
#   380: {1: 552, 2: 179, 3: 82, 4: 55, 5: 28, 6: 18, 7: 14, 8: 13},
#   381: {1: 452, 2: 195, 3: 129, 4: 78, 5: 30, 6: 23, 7: 22, 8: 22},
#   382: {1: 477, 2: 216, 3: 148, 4: 94, 5: 60, 6: 29, 7: 25, 8: 17},
#   383: {1: 450, 2: 179, 3: 105, 4: 67, 5: 42, 6: 31, 7: 25, 8: 22},
#   384: {1: 520, 2: 185, 3: 107, 4: 56, 5: 24, 6: 20, 7: 14, 8: 14},
#   385: {1: 510, 2: 185, 3: 107, 4: 52, 5: 31, 6: 20, 7: 16, 8: 15},
#   386: {1: 459, 2: 163, 3: 73, 4: 48, 5: 11, 6: 10, 7: 10, 8: 10},
#   387: {1: 420, 2: 214, 3: 160, 4: 116, 5: 41, 6: 23, 7: 20, 8: 19},
#   388: {1: 397, 2: 188, 3: 112, 4: 66, 5: 52, 6: 44, 7: 42, 8: 38},
#   389: {1: 549, 2: 238, 3: 135, 4: 69, 5: 37, 6: 28, 7: 19, 8: 19},
#   390: {1: 482, 2: 283, 3: 187, 4: 135, 5: 61, 6: 39, 7: 27, 8: 25},
#   391: {1: 486, 2: 209, 3: 118, 4: 57, 5: 34, 6: 24, 7: 20, 8: 19},
#   392: {1: 498, 2: 133, 3: 58, 4: 36, 5: 24, 6: 17, 7: 16, 8: 14},
#   393: {1: 563, 2: 293, 3: 175, 4: 112, 5: 66, 6: 42, 7: 36, 8: 32},
#   394: {1: 391, 2: 188, 3: 108, 4: 70, 5: 38, 6: 29, 7: 23, 8: 22},
#   395: {1: 503, 2: 204, 3: 124, 4: 61, 5: 21, 6: 14, 7: 10, 8: 9},
#   396: {1: 524, 2: 241, 3: 189, 4: 128, 5: 42, 6: 27, 7: 17, 8: 13},
#   397: {1: 298, 2: 120, 3: 92, 4: 57, 5: 32, 6: 16, 7: 15, 8: 13},
#   398: {1: 532, 2: 250, 3: 134, 4: 51, 5: 26, 6: 25, 7: 19, 8: 15},
#   399: {1: 460, 2: 199, 3: 117, 4: 82, 5: 41, 6: 25, 7: 22, 8: 19},
#   400: {1: 526, 2: 175, 3: 94, 4: 67, 5: 40, 6: 31, 7: 22, 8: 22},
#   401: {1: 447, 2: 215, 3: 111, 4: 77, 5: 41, 6: 33, 7: 33, 8: 27},
#   402: {1: 540, 2: 168, 3: 117, 4: 66, 5: 33, 6: 20, 7: 15, 8: 14},
#   403: {1: 467, 2: 165, 3: 101, 4: 80, 5: 30, 6: 22, 7: 21, 8: 17},
#   404: {1: 429, 2: 153, 3: 75, 4: 39, 5: 24, 6: 18, 7: 15, 8: 15},
#   405: {1: 526, 2: 215, 3: 140, 4: 87, 5: 50, 6: 25, 7: 18, 8: 18},
#   406: {1: 427, 2: 203, 3: 138, 4: 91, 5: 52, 6: 30, 7: 28, 8: 27},
#   407: {1: 421, 2: 122, 3: 73, 4: 56, 5: 29, 6: 25, 7: 24, 8: 24},
#   408: {1: 481, 2: 162, 3: 98, 4: 67, 5: 42, 6: 35, 7: 25, 8: 20},
#   409: {1: 473, 2: 199, 3: 126, 4: 77, 5: 31, 6: 17, 7: 15, 8: 14},
#   410: {1: 557, 2: 151, 3: 98, 4: 54, 5: 34, 6: 20, 7: 18, 8: 16},
#   411: {1: 598, 2: 284, 3: 160, 4: 98, 5: 54, 6: 25, 7: 22, 8: 18},
#   412: {1: 471, 2: 221, 3: 138, 4: 73, 5: 33, 6: 27, 7: 25, 8: 22},
#   413: {1: 566, 2: 246, 3: 161, 4: 78, 5: 49, 6: 28, 7: 24, 8: 20},
#   414: {1: 444, 2: 227, 3: 139, 4: 70, 5: 39, 6: 21, 7: 17, 8: 16},
#   415: {1: 467, 2: 231, 3: 148, 4: 40, 5: 28, 6: 21, 7: 16, 8: 14},
#   416: {1: 393, 2: 167, 3: 82, 4: 62, 5: 36, 6: 23, 7: 20, 8: 17},
#   417: {1: 501, 2: 141, 3: 90, 4: 55, 5: 33, 6: 23, 7: 20, 8: 19},
#   418: {1: 450, 2: 159, 3: 107, 4: 51, 5: 31, 6: 23, 7: 16, 8: 15},
#   419: {1: 533, 2: 242, 3: 145, 4: 105, 5: 35, 6: 10, 7: 8, 8: 8},
#   420: {1: 511, 2: 262, 3: 144, 4: 91, 5: 46, 6: 27, 7: 22, 8: 22},
#   421: {1: 565, 2: 236, 3: 154, 4: 90, 5: 51, 6: 37, 7: 35, 8: 35},
#   422: {1: 467, 2: 221, 3: 148, 4: 109, 5: 55, 6: 50, 7: 24, 8: 20},
#   423: {1: 632, 2: 340, 3: 227, 4: 135, 5: 96, 6: 67, 7: 62, 8: 57},
#   424: {1: 490, 2: 208, 3: 154, 4: 95, 5: 55, 6: 40, 7: 26, 8: 23},
#   425: {1: 498, 2: 230, 3: 128, 4: 49, 5: 28, 6: 19, 7: 14, 8: 14},
#   426: {1: 488, 2: 168, 3: 110, 4: 54, 5: 38, 6: 26, 7: 24, 8: 23},
#   427: {1: 469, 2: 202, 3: 106, 4: 56, 5: 26, 6: 18, 7: 13, 8: 13},
#   428: {1: 482, 2: 196, 3: 125, 4: 87, 5: 50, 6: 43, 7: 38, 8: 34},
#   429: {1: 531, 2: 255, 3: 159, 4: 76, 5: 48, 6: 36, 7: 21, 8: 19},
#   430: {1: 493, 2: 247, 3: 165, 4: 84, 5: 30, 6: 19, 7: 18, 8: 17},
#   431: {1: 461, 2: 184, 3: 128, 4: 60, 5: 38, 6: 23, 7: 15, 8: 13},
#   432: {1: 585, 2: 296, 3: 203, 4: 121, 5: 52, 6: 37, 7: 26, 8: 26},
#   433: {1: 590, 2: 255, 3: 158, 4: 94, 5: 57, 6: 41, 7: 27, 8: 25},
#   434: {1: 550, 2: 224, 3: 135, 4: 63, 5: 33, 6: 16, 7: 14, 8: 14},
#   435: {1: 453, 2: 196, 3: 120, 4: 80, 5: 45, 6: 38, 7: 27, 8: 25},
#   436: {1: 536, 2: 221, 3: 133, 4: 85, 5: 33, 6: 26, 7: 25, 8: 22},
#   437: {1: 517, 2: 193, 3: 148, 4: 86, 5: 46, 6: 33, 7: 27, 8: 25},
#   438: {1: 424, 2: 195, 3: 129, 4: 87, 5: 44, 6: 20, 7: 14, 8: 13},
#   439: {1: 475, 2: 226, 3: 149, 4: 80, 5: 46, 6: 39, 7: 36, 8: 35},
#   440: {1: 529, 2: 213, 3: 101, 4: 53, 5: 44, 6: 29, 7: 16, 8: 16},
#   441: {1: 504, 2: 183, 3: 97, 4: 63, 5: 26, 6: 20, 7: 17, 8: 17},
#   442: {1: 474, 2: 199, 3: 110, 4: 83, 5: 43, 6: 24, 7: 17, 8: 17},
#   443: {1: 524, 2: 270, 3: 140, 4: 99, 5: 60, 6: 33, 7: 26, 8: 26},
#   444: {1: 589, 2: 220, 3: 119, 4: 68, 5: 26, 6: 15, 7: 13, 8: 10},
#   445: {1: 569, 2: 265, 3: 174, 4: 100, 5: 50, 6: 34, 7: 29, 8: 23},
#   446: {1: 481, 2: 175, 3: 111, 4: 78, 5: 40, 6: 14, 7: 14, 8: 13},
#   447: {1: 506, 2: 154, 3: 89, 4: 59, 5: 25, 6: 24, 7: 16, 8: 13},
#   448: {1: 463, 2: 251, 3: 189, 4: 102, 5: 53, 6: 44, 7: 33, 8: 30},
#   449: {1: 493, 2: 146, 3: 107, 4: 55, 5: 23, 6: 17, 7: 14, 8: 13},
#   450: {1: 514, 2: 249, 3: 154, 4: 73, 5: 45, 6: 24, 7: 19, 8: 17},
#   451: {1: 496, 2: 198, 3: 95, 4: 75, 5: 38, 6: 25, 7: 19, 8: 15},
#   452: {1: 476, 2: 250, 3: 162, 4: 80, 5: 46, 6: 40, 7: 33, 8: 29},
#   453: {1: 443, 2: 182, 3: 86, 4: 57, 5: 37, 6: 14, 7: 11, 8: 11},
#   454: {1: 476, 2: 250, 3: 151, 4: 98, 5: 48, 6: 19, 7: 12, 8: 8},
#   455: {1: 482, 2: 169, 3: 93, 4: 53, 5: 35, 6: 26, 7: 20, 8: 19},
#   456: {1: 410, 2: 126, 3: 83, 4: 35, 5: 24, 6: 21, 7: 20, 8: 18},
#   457: {1: 476, 2: 178, 3: 96, 4: 57, 5: 36, 6: 30, 7: 24, 8: 22},
#   458: {1: 498, 2: 138, 3: 75, 4: 40, 5: 26, 6: 22, 7: 19, 8: 19},
#   459: {1: 463, 2: 182, 3: 133, 4: 85, 5: 43, 6: 29, 7: 25, 8: 22},
#   460: {1: 560, 2: 228, 3: 126, 4: 81, 5: 38, 6: 22, 7: 20, 8: 18},
#   461: {1: 576, 2: 291, 3: 177, 4: 108, 5: 63, 6: 35, 7: 27, 8: 22},
#   462: {1: 471, 2: 206, 3: 130, 4: 66, 5: 35, 6: 17, 7: 13, 8: 13},
#   463: {1: 466, 2: 205, 3: 113, 4: 82, 5: 47, 6: 34, 7: 25, 8: 17},
#   464: {1: 466, 2: 144, 3: 101, 4: 60, 5: 32, 6: 28, 7: 17, 8: 17},
#   465: {1: 527, 2: 315, 3: 217, 4: 140, 5: 68, 6: 42, 7: 23, 8: 20},
#   466: {1: 515, 2: 256, 3: 135, 4: 96, 5: 62, 6: 33, 7: 27, 8: 26},
#   467: {1: 435, 2: 112, 3: 69, 4: 50, 5: 23, 6: 17, 7: 14, 8: 13},
#   468: {1: 598, 2: 205, 3: 94, 4: 68, 5: 33, 6: 27, 7: 26, 8: 23},
#   469: {1: 462, 2: 184, 3: 119, 4: 82, 5: 53, 6: 15, 7: 13, 8: 13},
#   470: {1: 427, 2: 189, 3: 136, 4: 78, 5: 47, 6: 26, 7: 21, 8: 19},
#   471: {1: 466, 2: 225, 3: 130, 4: 77, 5: 40, 6: 35, 7: 30, 8: 27},
#   472: {1: 475, 2: 161, 3: 95, 4: 63, 5: 27, 6: 16, 7: 12, 8: 12},
#   473: {1: 477, 2: 236, 3: 139, 4: 109, 5: 66, 6: 39, 7: 34, 8: 31},
#   474: {1: 548, 2: 171, 3: 111, 4: 87, 5: 48, 6: 25, 7: 18, 8: 15},
#   475: {1: 433, 2: 192, 3: 131, 4: 90, 5: 49, 6: 33, 7: 23, 8: 19},
#   476: {1: 472, 2: 217, 3: 121, 4: 73, 5: 42, 6: 18, 7: 12, 8: 12},
#   477: {1: 606, 2: 250, 3: 116, 4: 66, 5: 40, 6: 25, 7: 18, 8: 18},
#   478: {1: 479, 2: 202, 3: 136, 4: 83, 5: 44, 6: 26, 7: 23, 8: 21},
#   479: {1: 433, 2: 121, 3: 83, 4: 53, 5: 30, 6: 23, 7: 19, 8: 16},
#   480: {1: 566, 2: 266, 3: 174, 4: 132, 5: 61, 6: 45, 7: 30, 8: 28},
#   481: {1: 443, 2: 184, 3: 127, 4: 72, 5: 24, 6: 15, 7: 13, 8: 10},
#   482: {1: 482, 2: 256, 3: 214, 4: 139, 5: 80, 6: 59, 7: 54, 8: 50},
#   483: {1: 433, 2: 162, 3: 107, 4: 77, 5: 46, 6: 31, 7: 26, 8: 23},
#   484: {1: 398, 2: 162, 3: 94, 4: 55, 5: 28, 6: 17, 7: 15, 8: 12},
#   485: {1: 434, 2: 209, 3: 132, 4: 86, 5: 50, 6: 25, 7: 19, 8: 17},
#   486: {1: 486, 2: 170, 3: 115, 4: 63, 5: 26, 6: 18, 7: 14, 8: 14},
#   487: {1: 437, 2: 161, 3: 75, 4: 51, 5: 21, 6: 13, 7: 9, 8: 7},
#   488: {1: 528, 2: 223, 3: 120, 4: 85, 5: 48, 6: 34, 7: 28, 8: 27},
#   489: {1: 316, 2: 98, 3: 56, 4: 39, 5: 24, 6: 19, 7: 19, 8: 15},
#   490: {1: 533, 2: 182, 3: 128, 4: 85, 5: 49, 6: 32, 7: 31, 8: 26},
#   491: {1: 556, 2: 176, 3: 107, 4: 58, 5: 22, 6: 9, 7: 7, 8: 5},
#   492: {1: 592, 2: 220, 3: 120, 4: 87, 5: 51, 6: 33, 7: 29, 8: 25},
#   493: {1: 473, 2: 145, 3: 97, 4: 44, 5: 26, 6: 17, 7: 16, 8: 16},
#   494: {1: 314, 2: 91, 3: 62, 4: 36, 5: 21, 6: 15, 7: 15, 8: 13},
#   495: {1: 537, 2: 259, 3: 143, 4: 79, 5: 50, 6: 43, 7: 39, 8: 34},
#   496: {1: 552, 2: 206, 3: 114, 4: 64, 5: 32, 6: 23, 7: 19, 8: 18},
#   497: {1: 526, 2: 192, 3: 120, 4: 76, 5: 40, 6: 33, 7: 29, 8: 28},
#   498: {1: 406, 2: 116, 3: 69, 4: 41, 5: 26, 6: 25, 7: 16, 8: 15},
#   499: {1: 498, 2: 176, 3: 127, 4: 85, 5: 50, 6: 39, 7: 28, 8: 26},
#   500: {1: 419, 2: 137, 3: 76, 4: 51, 5: 33, 6: 13, 7: 8, 8: 8},
#   501: {1: 488, 2: 192, 3: 113, 4: 84, 5: 39, 6: 28, 7: 21, 8: 17},
#   502: {1: 516, 2: 207, 3: 147, 4: 77, 5: 36, 6: 27, 7: 20, 8: 15},
#   503: {1: 441, 2: 163, 3: 84, 4: 49, 5: 17, 6: 16, 7: 13, 8: 10},
#   504: {1: 444, 2: 177, 3: 114, 4: 65, 5: 37, 6: 24, 7: 6, 8: 5},
#   505: {1: 486, 2: 162, 3: 102, 4: 61, 5: 47, 6: 30, 7: 22, 8: 17},
#   506: {1: 479, 2: 127, 3: 88, 4: 28, 5: 13, 6: 7, 7: 5, 8: 4},
#   507: {1: 526, 2: 207, 3: 134, 4: 58, 5: 37, 6: 18, 7: 15, 8: 13},
#   508: {1: 558, 2: 309, 3: 187, 4: 138, 5: 65, 6: 56, 7: 34, 8: 34},
#   509: {1: 424, 2: 188, 3: 96, 4: 81, 5: 41, 6: 16, 7: 16, 8: 16},
#   510: {1: 552, 2: 227, 3: 151, 4: 88, 5: 53, 6: 31, 7: 28, 8: 27},
#   511: {1: 481, 2: 247, 3: 158, 4: 99, 5: 55, 6: 48, 7: 42, 8: 37},
#   512: {1: 460, 2: 200, 3: 124, 4: 78, 5: 38, 6: 17, 7: 15, 8: 14},
#   513: {1: 442, 2: 263, 3: 156, 4: 87, 5: 48, 6: 38, 7: 32, 8: 28},
#   514: {1: 454, 2: 165, 3: 89, 4: 48, 5: 26, 6: 15, 7: 12, 8: 11},
#   515: {1: 438, 2: 179, 3: 118, 4: 74, 5: 38, 6: 28, 7: 25, 8: 21},
#   516: {1: 475, 2: 194, 3: 137, 4: 82, 5: 46, 6: 29, 7: 23, 8: 23},
#   517: {1: 509, 2: 235, 3: 111, 4: 72, 5: 47, 6: 34, 7: 29, 8: 25},
#   518: {1: 488, 2: 200, 3: 109, 4: 57, 5: 26, 6: 25, 7: 18, 8: 15},
#   519: {1: 376, 2: 180, 3: 119, 4: 62, 5: 26, 6: 17, 7: 14, 8: 14},
#   520: {1: 517, 2: 208, 3: 85, 4: 55, 5: 25, 6: 22, 7: 20, 8: 20},
#   521: {1: 537, 2: 279, 3: 176, 4: 123, 5: 64, 6: 43, 7: 35, 8: 34},
#   522: {1: 461, 2: 229, 3: 106, 4: 58, 5: 30, 6: 20, 7: 20, 8: 19},
#   523: {1: 452, 2: 146, 3: 73, 4: 64, 5: 27, 6: 15, 7: 13, 8: 13},
#   524: {1: 475, 2: 205, 3: 135, 4: 90, 5: 51, 6: 34, 7: 24, 8: 19},
#   525: {1: 452, 2: 150, 3: 79, 4: 40, 5: 24, 6: 12, 7: 7, 8: 7},
#   526: {1: 494, 2: 137, 3: 69, 4: 51, 5: 36, 6: 27, 7: 24, 8: 22},
#   527: {1: 532, 2: 133, 3: 84, 4: 52, 5: 25, 6: 18, 7: 11, 8: 11},
#   528: {1: 494, 2: 297, 3: 151, 4: 63, 5: 38, 6: 19, 7: 12, 8: 11},
#   529: {1: 425, 2: 174, 3: 86, 4: 44, 5: 24, 6: 13, 7: 9, 8: 7},
#   530: {1: 463, 2: 161, 3: 110, 4: 76, 5: 34, 6: 27, 7: 23, 8: 22},
#   531: {1: 520, 2: 222, 3: 138, 4: 84, 5: 51, 6: 46, 7: 35, 8: 31},
#   532: {1: 546, 2: 239, 3: 166, 4: 101, 5: 44, 6: 26, 7: 17, 8: 14},
#   533: {1: 548, 2: 298, 3: 133, 4: 91, 5: 54, 6: 34, 7: 27, 8: 27},
#   534: {1: 526, 2: 192, 3: 105, 4: 70, 5: 28, 6: 18, 7: 10, 8: 10},
#   535: {1: 432, 2: 188, 3: 137, 4: 77, 5: 49, 6: 30, 7: 20, 8: 19},
#   536: {1: 550, 2: 222, 3: 123, 4: 80, 5: 33, 6: 18, 7: 15, 8: 13},
#   537: {1: 509, 2: 130, 3: 81, 4: 51, 5: 25, 6: 23, 7: 15, 8: 15},
#   538: {1: 513, 2: 219, 3: 121, 4: 72, 5: 49, 6: 26, 7: 22, 8: 17},
#   539: {1: 427, 2: 118, 3: 60, 4: 33, 5: 21, 6: 10, 7: 6, 8: 6},
#   540: {1: 502, 2: 244, 3: 127, 4: 71, 5: 26, 6: 14, 7: 14, 8: 14},
#   541: {1: 540, 2: 253, 3: 140, 4: 67, 5: 39, 6: 24, 7: 19, 8: 16},
#   542: {1: 534, 2: 266, 3: 182, 4: 146, 5: 89, 6: 69, 7: 59, 8: 59},
#   543: {1: 377, 2: 152, 3: 80, 4: 62, 5: 30, 6: 22, 7: 14, 8: 13},
#   544: {1: 506, 2: 154, 3: 81, 4: 46, 5: 34, 6: 25, 7: 17, 8: 15},
#   545: {1: 485, 2: 185, 3: 121, 4: 84, 5: 64, 6: 41, 7: 35, 8: 31},
#   546: {1: 490, 2: 200, 3: 105, 4: 62, 5: 29, 6: 21, 7: 17, 8: 13},
#   547: {1: 455, 2: 177, 3: 118, 4: 68, 5: 37, 6: 11, 7: 10, 8: 10},
#   548: {1: 465, 2: 189, 3: 87, 4: 48, 5: 24, 6: 22, 7: 20, 8: 20},
#   549: {1: 422, 2: 167, 3: 102, 4: 57, 5: 35, 6: 26, 7: 22, 8: 19},
#   550: {1: 571, 2: 197, 3: 127, 4: 91, 5: 63, 6: 45, 7: 34, 8: 33},
#   551: {1: 486, 2: 133, 3: 88, 4: 58, 5: 37, 6: 34, 7: 29, 8: 27},
#   552: {1: 603, 2: 209, 3: 152, 4: 77, 5: 53, 6: 39, 7: 34, 8: 31},
#   553: {1: 395, 2: 249, 3: 158, 4: 80, 5: 40, 6: 14, 7: 9, 8: 8},
#   554: {1: 454, 2: 157, 3: 109, 4: 60, 5: 41, 6: 28, 7: 21, 8: 20},
#   555: {1: 464, 2: 199, 3: 118, 4: 59, 5: 36, 6: 25, 7: 16, 8: 14},
#   556: {1: 538, 2: 208, 3: 112, 4: 81, 5: 42, 6: 34, 7: 27, 8: 25},
#   557: {1: 510, 2: 236, 3: 158, 4: 91, 5: 50, 6: 43, 7: 31, 8: 27},
#   558: {1: 478, 2: 185, 3: 104, 4: 65, 5: 29, 6: 19, 7: 15, 8: 14},
#   559: {1: 489, 2: 180, 3: 88, 4: 51, 5: 34, 6: 14, 7: 10, 8: 9},
#   560: {1: 486, 2: 217, 3: 109, 4: 67, 5: 44, 6: 22, 7: 16, 8: 13},
#   561: {1: 443, 2: 186, 3: 129, 4: 74, 5: 47, 6: 35, 7: 32, 8: 32},
#   562: {1: 495, 2: 198, 3: 132, 4: 77, 5: 38, 6: 31, 7: 31, 8: 30},
#   563: {1: 415, 2: 171, 3: 107, 4: 74, 5: 42, 6: 28, 7: 20, 8: 19},
#   564: {1: 558, 2: 256, 3: 144, 4: 105, 5: 50, 6: 33, 7: 28, 8: 27},
#   565: {1: 422, 2: 195, 3: 133, 4: 85, 5: 48, 6: 37, 7: 25, 8: 23},
#   566: {1: 443, 2: 161, 3: 107, 4: 73, 5: 53, 6: 38, 7: 33, 8: 33},
#   567: {1: 453, 2: 179, 3: 109, 4: 78, 5: 49, 6: 38, 7: 28, 8: 26},
#   568: {1: 434, 2: 233, 3: 148, 4: 107, 5: 39, 6: 31, 7: 21, 8: 20},
#   569: {1: 521, 2: 186, 3: 114, 4: 75, 5: 50, 6: 25, 7: 24, 8: 21},
#   570: {1: 457, 2: 208, 3: 145, 4: 99, 5: 68, 6: 51, 7: 36, 8: 36},
#   571: {1: 491, 2: 235, 3: 175, 4: 103, 5: 62, 6: 40, 7: 36, 8: 36},
#   572: {1: 428, 2: 161, 3: 108, 4: 71, 5: 36, 6: 21, 7: 18, 8: 17},
#   573: {1: 416, 2: 137, 3: 90, 4: 65, 5: 40, 6: 34, 7: 27, 8: 23},
#   574: {1: 423, 2: 197, 3: 132, 4: 84, 5: 33, 6: 18, 7: 17, 8: 15},
#   575: {1: 441, 2: 173, 3: 102, 4: 63, 5: 30, 6: 21, 7: 21, 8: 19},
#   576: {1: 470, 2: 226, 3: 105, 4: 72, 5: 42, 6: 33, 7: 31, 8: 26},
#   577: {1: 483, 2: 213, 3: 104, 4: 63, 5: 34, 6: 15, 7: 15, 8: 13},
#   578: {1: 555, 2: 262, 3: 130, 4: 78, 5: 49, 6: 40, 7: 35, 8: 32},
#   579: {1: 435, 2: 205, 3: 115, 4: 72, 5: 38, 6: 27, 7: 21, 8: 17},
#   580: {1: 499, 2: 215, 3: 97, 4: 71, 5: 37, 6: 27, 7: 22, 8: 21},
#   581: {1: 473, 2: 202, 3: 140, 4: 90, 5: 54, 6: 45, 7: 32, 8: 30},
#   582: {1: 471, 2: 204, 3: 123, 4: 86, 5: 56, 6: 52, 7: 43, 8: 41},
#   583: {1: 533, 2: 230, 3: 142, 4: 82, 5: 34, 6: 28, 7: 24, 8: 19},
#   584: {1: 580, 2: 263, 3: 165, 4: 110, 5: 45, 6: 42, 7: 33, 8: 29},
#   585: {1: 483, 2: 274, 3: 163, 4: 103, 5: 52, 6: 45, 7: 41, 8: 40},
#   586: {1: 531, 2: 235, 3: 156, 4: 81, 5: 59, 6: 36, 7: 25, 8: 22},
#   587: {1: 438, 2: 169, 3: 87, 4: 46, 5: 30, 6: 25, 7: 25, 8: 21},
#   588: {1: 437, 2: 172, 3: 125, 4: 83, 5: 50, 6: 33, 7: 25, 8: 24},
#   589: {1: 416, 2: 144, 3: 103, 4: 60, 5: 29, 6: 14, 7: 12, 8: 12},
#   590: {1: 356, 2: 111, 3: 65, 4: 38, 5: 21, 6: 13, 7: 9, 8: 9},
#   591: {1: 487, 2: 196, 3: 122, 4: 86, 5: 51, 6: 32, 7: 31, 8: 31},
#   592: {1: 463, 2: 198, 3: 140, 4: 101, 5: 70, 6: 55, 7: 38, 8: 35},
#   593: {1: 341, 2: 139, 3: 82, 4: 49, 5: 30, 6: 17, 7: 6, 8: 6},
#   594: {1: 484, 2: 232, 3: 152, 4: 84, 5: 50, 6: 18, 7: 14, 8: 12},
#   595: {1: 491, 2: 159, 3: 87, 4: 56, 5: 30, 6: 21, 7: 20, 8: 20},
#   596: {1: 350, 2: 139, 3: 98, 4: 72, 5: 42, 6: 30, 7: 29, 8: 22},
#   597: {1: 450, 2: 167, 3: 119, 4: 80, 5: 53, 6: 39, 7: 39, 8: 37},
#   598: {1: 576, 2: 293, 3: 183, 4: 129, 5: 85, 6: 44, 7: 33, 8: 31},
#   599: {1: 492, 2: 238, 3: 153, 4: 96, 5: 49, 6: 34, 7: 22, 8: 19},
#   600: {1: 655, 2: 254, 3: 204, 4: 110, 5: 63, 6: 48, 7: 31, 8: 26},
#   601: {1: 490, 2: 260, 3: 157, 4: 111, 5: 69, 6: 54, 7: 47, 8: 41},
#   602: {1: 409, 2: 162, 3: 100, 4: 53, 5: 27, 6: 25, 7: 22, 8: 18},
#   603: {1: 512, 2: 215, 3: 125, 4: 84, 5: 56, 6: 40, 7: 32, 8: 28},
#   604: {1: 462, 2: 206, 3: 152, 4: 98, 5: 49, 6: 31, 7: 22, 8: 22},
#   605: {1: 440, 2: 188, 3: 112, 4: 71, 5: 41, 6: 27, 7: 25, 8: 24},
#   606: {1: 533, 2: 254, 3: 176, 4: 103, 5: 61, 6: 44, 7: 43, 8: 39},
#   607: {1: 463, 2: 166, 3: 103, 4: 52, 5: 34, 6: 33, 7: 24, 8: 22},
#   608: {1: 474, 2: 225, 3: 156, 4: 89, 5: 44, 6: 21, 7: 6, 8: 6},
#   609: {1: 450, 2: 143, 3: 92, 4: 58, 5: 32, 6: 26, 7: 25, 8: 24},
#   610: {1: 459, 2: 189, 3: 99, 4: 68, 5: 46, 6: 28, 7: 21, 8: 20},
#   611: {1: 377, 2: 171, 3: 110, 4: 72, 5: 28, 6: 23, 7: 18, 8: 15},
#   612: {1: 504, 2: 238, 3: 153, 4: 89, 5: 47, 6: 43, 7: 33, 8: 32},
#   613: {1: 447, 2: 154, 3: 92, 4: 59, 5: 29, 6: 14, 7: 10, 8: 9},
#   614: {1: 489, 2: 198, 3: 125, 4: 79, 5: 38, 6: 28, 7: 19, 8: 17},
#   615: {1: 473, 2: 158, 3: 86, 4: 48, 5: 24, 6: 18, 7: 15, 8: 13},
#   616: {1: 514, 2: 248, 3: 143, 4: 95, 5: 40, 6: 37, 7: 28, 8: 28},
#   617: {1: 506, 2: 200, 3: 93, 4: 58, 5: 35, 6: 32, 7: 21, 8: 19},
#   618: {1: 575, 2: 308, 3: 197, 4: 105, 5: 57, 6: 36, 7: 34, 8: 29},
#   619: {1: 495, 2: 202, 3: 117, 4: 67, 5: 26, 6: 22, 7: 15, 8: 14},
#   620: {1: 447, 2: 165, 3: 95, 4: 59, 5: 26, 6: 21, 7: 17, 8: 17},
#   621: {1: 504, 2: 217, 3: 148, 4: 108, 5: 61, 6: 40, 7: 33, 8: 22},
#   622: {1: 531, 2: 216, 3: 130, 4: 63, 5: 38, 6: 28, 7: 20, 8: 19},
#   623: {1: 481, 2: 231, 3: 110, 4: 82, 5: 50, 6: 47, 7: 45, 8: 45},
#   624: {1: 417, 2: 147, 3: 94, 4: 68, 5: 34, 6: 15, 7: 9, 8: 7},
#   625: {1: 502, 2: 178, 3: 121, 4: 78, 5: 24, 6: 12, 7: 8, 8: 8},
#   626: {1: 477, 2: 200, 3: 126, 4: 86, 5: 46, 6: 34, 7: 23, 8: 23},
#   627: {1: 420, 2: 228, 3: 136, 4: 82, 5: 52, 6: 30, 7: 25, 8: 23},
#   628: {1: 612, 2: 249, 3: 133, 4: 60, 5: 27, 6: 22, 7: 20, 8: 17},
#   629: {1: 504, 2: 276, 3: 200, 4: 120, 5: 53, 6: 34, 7: 32, 8: 24},
#   630: {1: 513, 2: 184, 3: 131, 4: 79, 5: 42, 6: 28, 7: 21, 8: 18},
#   631: {1: 421, 2: 200, 3: 100, 4: 62, 5: 36, 6: 25, 7: 18, 8: 17},
#   632: {1: 469, 2: 203, 3: 126, 4: 52, 5: 30, 6: 21, 7: 18, 8: 17},
#   633: {1: 467, 2: 220, 3: 132, 4: 83, 5: 41, 6: 16, 7: 8, 8: 7},
#   634: {1: 478, 2: 180, 3: 140, 4: 78, 5: 45, 6: 33, 7: 25, 8: 25},
#   635: {1: 490, 2: 222, 3: 172, 4: 96, 5: 48, 6: 38, 7: 38, 8: 38},
#   636: {1: 322, 2: 164, 3: 90, 4: 70, 5: 39, 6: 35, 7: 26, 8: 23},
#   637: {1: 514, 2: 194, 3: 113, 4: 68, 5: 40, 6: 30, 7: 23, 8: 22},
#   638: {1: 475, 2: 216, 3: 103, 4: 53, 5: 25, 6: 19, 7: 18, 8: 16},
#   639: {1: 442, 2: 211, 3: 145, 4: 96, 5: 40, 6: 28, 7: 28, 8: 21},
#   640: {1: 459, 2: 232, 3: 143, 4: 93, 5: 41, 6: 28, 7: 19, 8: 17},
#   641: {1: 532, 2: 157, 3: 103, 4: 59, 5: 35, 6: 15, 7: 15, 8: 15},
#   642: {1: 412, 2: 163, 3: 119, 4: 90, 5: 57, 6: 51, 7: 47, 8: 42},
#   643: {1: 386, 2: 179, 3: 103, 4: 55, 5: 25, 6: 15, 7: 7, 8: 7},
#   644: {1: 422, 2: 193, 3: 118, 4: 74, 5: 24, 6: 18, 7: 14, 8: 13},
#   645: {1: 468, 2: 209, 3: 137, 4: 65, 5: 34, 6: 26, 7: 20, 8: 18},
#   646: {1: 471, 2: 211, 3: 119, 4: 67, 5: 41, 6: 21, 7: 18, 8: 17},
#   647: {1: 531, 2: 211, 3: 116, 4: 79, 5: 43, 6: 28, 7: 23, 8: 21},
#   648: {1: 526, 2: 196, 3: 107, 4: 67, 5: 43, 6: 37, 7: 35, 8: 28},
#   649: {1: 463, 2: 264, 3: 184, 4: 117, 5: 68, 6: 54, 7: 43, 8: 40},
#   650: {1: 506, 2: 265, 3: 162, 4: 88, 5: 49, 6: 33, 7: 25, 8: 25},
#   651: {1: 571, 2: 218, 3: 140, 4: 110, 5: 61, 6: 34, 7: 29, 8: 29},
#   652: {1: 474, 2: 207, 3: 100, 4: 65, 5: 43, 6: 27, 7: 22, 8: 20},
#   653: {1: 442, 2: 142, 3: 83, 4: 59, 5: 30, 6: 24, 7: 18, 8: 14},
#   654: {1: 431, 2: 219, 3: 125, 4: 89, 5: 51, 6: 35, 7: 24, 8: 21},
#   655: {1: 439, 2: 113, 3: 73, 4: 29, 5: 15, 6: 10, 7: 8, 8: 6},
#   656: {1: 621, 2: 270, 3: 156, 4: 103, 5: 44, 6: 34, 7: 25, 8: 23},
#   657: {1: 410, 2: 110, 3: 68, 4: 37, 5: 20, 6: 13, 7: 10, 8: 8},
#   658: {1: 451, 2: 180, 3: 105, 4: 53, 5: 25, 6: 21, 7: 13, 8: 11},
#   659: {1: 546, 2: 197, 3: 104, 4: 70, 5: 41, 6: 28, 7: 25, 8: 22},
#   660: {1: 432, 2: 143, 3: 77, 4: 43, 5: 28, 6: 11, 7: 11, 8: 11},
#   661: {1: 485, 2: 244, 3: 146, 4: 102, 5: 57, 6: 33, 7: 26, 8: 26},
#   662: {1: 477, 2: 210, 3: 149, 4: 75, 5: 46, 6: 33, 7: 31, 8: 25},
#   663: {1: 532, 2: 196, 3: 101, 4: 78, 5: 48, 6: 24, 7: 21, 8: 21},
#   664: {1: 405, 2: 110, 3: 69, 4: 48, 5: 33, 6: 24, 7: 18, 8: 16},
#   665: {1: 469, 2: 134, 3: 98, 4: 50, 5: 30, 6: 18, 7: 14, 8: 11},
#   666: {1: 487, 2: 162, 3: 97, 4: 71, 5: 30, 6: 22, 7: 15, 8: 14},
#   667: {1: 403, 2: 125, 3: 77, 4: 49, 5: 32, 6: 24, 7: 9, 8: 9},
#   668: {1: 581, 2: 253, 3: 117, 4: 62, 5: 21, 6: 10, 7: 8, 8: 7},
#   669: {1: 475, 2: 193, 3: 121, 4: 77, 5: 49, 6: 38, 7: 29, 8: 29},
#   670: {1: 512, 2: 225, 3: 110, 4: 67, 5: 38, 6: 24, 7: 24, 8: 22},
#   671: {1: 436, 2: 156, 3: 98, 4: 52, 5: 38, 6: 19, 7: 14, 8: 12},
#   672: {1: 375, 2: 137, 3: 62, 4: 28, 5: 20, 6: 16, 7: 13, 8: 13},
#   673: {1: 432, 2: 163, 3: 92, 4: 63, 5: 38, 6: 23, 7: 17, 8: 11},
#   674: {1: 540, 2: 214, 3: 111, 4: 74, 5: 44, 6: 28, 7: 24, 8: 22},
#   675: {1: 399, 2: 180, 3: 119, 4: 75, 5: 37, 6: 28, 7: 21, 8: 17},
#   676: {1: 497, 2: 212, 3: 131, 4: 78, 5: 54, 6: 37, 7: 32, 8: 27},
#   677: {1: 423, 2: 178, 3: 119, 4: 73, 5: 40, 6: 24, 7: 20, 8: 20},
#   678: {1: 490, 2: 186, 3: 106, 4: 74, 5: 33, 6: 30, 7: 22, 8: 22},
#   679: {1: 420, 2: 132, 3: 67, 4: 34, 5: 19, 6: 12, 7: 8, 8: 7},
#   680: {1: 518, 2: 263, 3: 112, 4: 78, 5: 33, 6: 28, 7: 26, 8: 22},
#   681: {1: 433, 2: 164, 3: 105, 4: 67, 5: 44, 6: 29, 7: 26, 8: 26},
#   682: {1: 525, 2: 192, 3: 109, 4: 60, 5: 40, 6: 32, 7: 24, 8: 19},
#   683: {1: 549, 2: 289, 3: 167, 4: 124, 5: 86, 6: 51, 7: 41, 8: 36},
#   684: {1: 418, 2: 140, 3: 63, 4: 43, 5: 22, 6: 18, 7: 14, 8: 12},
#   685: {1: 576, 2: 213, 3: 119, 4: 65, 5: 45, 6: 38, 7: 30, 8: 28},
#   686: {1: 486, 2: 186, 3: 90, 4: 68, 5: 26, 6: 17, 7: 13, 8: 11},
#   687: {1: 467, 2: 186, 3: 134, 4: 90, 5: 52, 6: 41, 7: 34, 8: 28},
#   688: {1: 544, 2: 172, 3: 90, 4: 67, 5: 43, 6: 22, 7: 17, 8: 17},
#   689: {1: 506, 2: 250, 3: 137, 4: 70, 5: 28, 6: 22, 7: 13, 8: 13},
#   690: {1: 504, 2: 253, 3: 136, 4: 67, 5: 33, 6: 25, 7: 19, 8: 14},
#   691: {1: 451, 2: 197, 3: 126, 4: 82, 5: 38, 6: 22, 7: 11, 8: 11},
#   692: {1: 320, 2: 113, 3: 68, 4: 44, 5: 27, 6: 14, 7: 13, 8: 13},
#   693: {1: 527, 2: 188, 3: 115, 4: 77, 5: 30, 6: 15, 7: 10, 8: 9},
#   694: {1: 439, 2: 135, 3: 71, 4: 48, 5: 27, 6: 21, 7: 21, 8: 19},
#   695: {1: 497, 2: 224, 3: 131, 4: 92, 5: 70, 6: 56, 7: 52, 8: 49},
#   696: {1: 470, 2: 193, 3: 96, 4: 60, 5: 38, 6: 32, 7: 27, 8: 21},
#   697: {1: 521, 2: 278, 3: 186, 4: 134, 5: 88, 6: 60, 7: 60, 8: 52},
#   698: {1: 496, 2: 219, 3: 121, 4: 89, 5: 51, 6: 32, 7: 25, 8: 24},
#   699: {1: 531, 2: 213, 3: 120, 4: 80, 5: 48, 6: 25, 7: 19, 8: 17},
#   700: {1: 447, 2: 193, 3: 132, 4: 92, 5: 44, 6: 38, 7: 33, 8: 29},
#   701: {1: 399, 2: 160, 3: 88, 4: 56, 5: 22, 6: 16, 7: 10, 8: 10},
#   702: {1: 522, 2: 243, 3: 123, 4: 68, 5: 43, 6: 29, 7: 21, 8: 16},
#   703: {1: 560, 2: 221, 3: 106, 4: 56, 5: 38, 6: 25, 7: 23, 8: 21},
#   704: {1: 493, 2: 135, 3: 90, 4: 50, 5: 28, 6: 17, 7: 13, 8: 13},
#   705: {1: 416, 2: 160, 3: 95, 4: 62, 5: 30, 6: 21, 7: 11, 8: 11},
#   706: {1: 417, 2: 175, 3: 121, 4: 83, 5: 45, 6: 32, 7: 24, 8: 22},
#   707: {1: 490, 2: 174, 3: 126, 4: 77, 5: 39, 6: 25, 7: 21, 8: 18},
#   708: {1: 533, 2: 254, 3: 180, 4: 145, 5: 74, 6: 49, 7: 39, 8: 31},
#   709: {1: 494, 2: 250, 3: 165, 4: 112, 5: 57, 6: 20, 7: 14, 8: 13},
#   710: {1: 557, 2: 261, 3: 158, 4: 94, 5: 49, 6: 32, 7: 24, 8: 20},
# ...
#   853: {1: 527, 2: 198, 3: 116, 4: 76, 5: 34, 6: 27, 7: 21, 8: 19},
#   854: {1: 425, 2: 175, 3: 81, 4: 52, 5: 29, 6: 23, 7: 21, 8: 17},
#   855: {1: 539, 2: 209, 3: 114, 4: 68, 5: 32, 6: 19, 7: 10, 8: 9},
#   856: {1: 451, 2: 192, 3: 95, 4: 57, 5: 28, 6: 25, 7: 21, 8: 21},
#   857: {1: 505, 2: 249, 3: 154, 4: 95, 5: 40, 6: 20, 7: 17, 8: 16},
#   858: {1: 410, 2: 193, 3: 121, 4: 61, 5: 33, 6: 20, 7: 15, 8: 15},
#   859: {1: 468, 2: 170, 3: 97, 4: 60, 5: 42, 6: 23, 7: 20, 8: 19},
#   860: {1: 506, 2: 193, 3: 136, 4: 78, 5: 39, 6: 21, 7: 18, 8: 18},
#   861: {1: 510, 2: 220, 3: 150, 4: 101, 5: 61, 6: 43, 7: 40, 8: 37},
#   862: {1: 444, 2: 194, 3: 107, 4: 71, 5: 39, 6: 25, 7: 21, 8: 21},
#   863: {1: 574, 2: 298, 3: 228, 4: 129, 5: 62, 6: 45, 7: 38, 8: 35},
#   864: {1: 542, 2: 226, 3: 124, 4: 49, 5: 24, 6: 18, 7: 14, 8: 10},
#   865: {1: 505, 2: 244, 3: 144, 4: 105, 5: 43, 6: 28, 7: 23, 8: 21},
#   866: {1: 540, 2: 217, 3: 137, 4: 70, 5: 40, 6: 31, 7: 27, 8: 23},
#   867: {1: 550, 2: 169, 3: 112, 4: 54, 5: 33, 6: 28, 7: 27, 8: 25},
#   868: {1: 442, 2: 229, 3: 101, 4: 63, 5: 43, 6: 27, 7: 23, 8: 22},
#   869: {1: 506, 2: 234, 3: 123, 4: 83, 5: 43, 6: 27, 7: 19, 8: 16},
#   870: {1: 425, 2: 190, 3: 92, 4: 57, 5: 24, 6: 19, 7: 15, 8: 15},
#   871: {1: 421, 2: 185, 3: 117, 4: 60, 5: 31, 6: 16, 7: 12, 8: 12},
#   872: {1: 546, 2: 203, 3: 95, 4: 38, 5: 17, 6: 13, 7: 9, 8: 7},
#   873: {1: 424, 2: 189, 3: 119, 4: 59, 5: 24, 6: 17, 7: 10, 8: 9},
#   874: {1: 466, 2: 181, 3: 103, 4: 59, 5: 44, 6: 26, 7: 24, 8: 20},
#   875: {1: 460, 2: 213, 3: 107, 4: 73, 5: 51, 6: 34, 7: 26, 8: 25},
#   876: {1: 359, 2: 190, 3: 135, 4: 62, 5: 40, 6: 26, 7: 21, 8: 16},
#   877: {1: 419, 2: 171, 3: 73, 4: 59, 5: 43, 6: 22, 7: 22, 8: 20},
#   878: {1: 404, 2: 156, 3: 107, 4: 66, 5: 37, 6: 28, 7: 25, 8: 24},
#   879: {1: 513, 2: 217, 3: 126, 4: 84, 5: 40, 6: 32, 7: 22, 8: 19},
#   880: {1: 481, 2: 188, 3: 108, 4: 59, 5: 36, 6: 14, 7: 9, 8: 8},
#   881: {1: 480, 2: 210, 3: 112, 4: 57, 5: 26, 6: 19, 7: 16, 8: 16},
#   882: {1: 457, 2: 202, 3: 143, 4: 87, 5: 49, 6: 28, 7: 22, 8: 19},
#   883: {1: 566, 2: 265, 3: 183, 4: 100, 5: 41, 6: 18, 7: 16, 8: 14},
#   884: {1: 471, 2: 204, 3: 130, 4: 74, 5: 41, 6: 35, 7: 30, 8: 28},
#   885: {1: 521, 2: 272, 3: 154, 4: 90, 5: 49, 6: 33, 7: 26, 8: 23},
#   886: {1: 440, 2: 186, 3: 129, 4: 95, 5: 47, 6: 35, 7: 34, 8: 29},
#   887: {1: 442, 2: 99, 3: 68, 4: 37, 5: 28, 6: 22, 7: 18, 8: 14},
#   888: {1: 543, 2: 234, 3: 167, 4: 94, 5: 41, 6: 30, 7: 27, 8: 25},
#   889: {1: 409, 2: 144, 3: 77, 4: 49, 5: 30, 6: 27, 7: 24, 8: 22},
#   890: {1: 514, 2: 175, 3: 124, 4: 80, 5: 48, 6: 32, 7: 26, 8: 23},
#   891: {1: 496, 2: 231, 3: 163, 4: 93, 5: 51, 6: 29, 7: 23, 8: 22},
#   892: {1: 457, 2: 143, 3: 86, 4: 68, 5: 47, 6: 32, 7: 29, 8: 26},
#   893: {1: 501, 2: 273, 3: 189, 4: 102, 5: 54, 6: 35, 7: 33, 8: 29},
#   894: {1: 485, 2: 187, 3: 119, 4: 84, 5: 44, 6: 25, 7: 22, 8: 18},
#   895: {1: 452, 2: 247, 3: 131, 4: 81, 5: 52, 6: 44, 7: 26, 8: 24},
#   896: {1: 447, 2: 197, 3: 137, 4: 94, 5: 46, 6: 28, 7: 22, 8: 17},
#   897: {1: 434, 2: 214, 3: 160, 4: 74, 5: 42, 6: 25, 7: 20, 8: 19},
#   898: {1: 535, 2: 227, 3: 148, 4: 79, 5: 50, 6: 28, 7: 24, 8: 20},
#   899: {1: 497, 2: 266, 3: 128, 4: 87, 5: 54, 6: 38, 7: 33, 8: 30},
#   900: {1: 441, 2: 181, 3: 96, 4: 52, 5: 22, 6: 18, 7: 13, 8: 13},
#   901: {1: 524, 2: 278, 3: 219, 4: 118, 5: 57, 6: 36, 7: 18, 8: 16},
#   902: {1: 440, 2: 190, 3: 124, 4: 67, 5: 40, 6: 27, 7: 19, 8: 18},
#   903: {1: 497, 2: 220, 3: 133, 4: 88, 5: 39, 6: 27, 7: 21, 8: 19},
#   904: {1: 533, 2: 276, 3: 183, 4: 121, 5: 68, 6: 50, 7: 43, 8: 36},
#   905: {1: 529, 2: 193, 3: 118, 4: 92, 5: 52, 6: 38, 7: 24, 8: 15},
#   906: {1: 436, 2: 187, 3: 114, 4: 68, 5: 25, 6: 17, 7: 16, 8: 15},
#   907: {1: 512, 2: 207, 3: 117, 4: 77, 5: 37, 6: 26, 7: 20, 8: 20},
#   908: {1: 528, 2: 226, 3: 124, 4: 74, 5: 45, 6: 29, 7: 22, 8: 19},
#   909: {1: 543, 2: 229, 3: 127, 4: 94, 5: 60, 6: 23, 7: 18, 8: 15},
#   910: {1: 468, 2: 219, 3: 139, 4: 87, 5: 42, 6: 29, 7: 24, 8: 20},
#   911: {1: 451, 2: 145, 3: 111, 4: 71, 5: 40, 6: 17, 7: 11, 8: 9},
#   912: {1: 543, 2: 194, 3: 119, 4: 81, 5: 45, 6: 30, 7: 19, 8: 19},
#   913: {1: 448, 2: 217, 3: 128, 4: 82, 5: 29, 6: 18, 7: 17, 8: 16},
#   914: {1: 430, 2: 226, 3: 161, 4: 118, 5: 59, 6: 42, 7: 13, 8: 12},
#   915: {1: 430, 2: 161, 3: 83, 4: 53, 5: 34, 6: 22, 7: 19, 8: 17},
#   916: {1: 535, 2: 244, 3: 177, 4: 119, 5: 54, 6: 40, 7: 32, 8: 31},
#   917: {1: 493, 2: 215, 3: 132, 4: 74, 5: 35, 6: 29, 7: 25, 8: 19},
#   918: {1: 455, 2: 164, 3: 112, 4: 73, 5: 40, 6: 20, 7: 20, 8: 19},
#   919: {1: 498, 2: 216, 3: 153, 4: 91, 5: 51, 6: 37, 7: 27, 8: 25},
#   920: {1: 545, 2: 246, 3: 157, 4: 96, 5: 40, 6: 32, 7: 25, 8: 25},
#   921: {1: 574, 2: 243, 3: 144, 4: 90, 5: 62, 6: 56, 7: 38, 8: 36},
#   922: {1: 523, 2: 162, 3: 92, 4: 60, 5: 30, 6: 21, 7: 16, 8: 13},
#   923: {1: 543, 2: 172, 3: 100, 4: 63, 5: 34, 6: 26, 7: 22, 8: 20},
#   924: {1: 449, 2: 200, 3: 134, 4: 82, 5: 44, 6: 22, 7: 19, 8: 18},
#   925: {1: 439, 2: 246, 3: 144, 4: 86, 5: 43, 6: 35, 7: 31, 8: 28},
#   926: {1: 499, 2: 172, 3: 116, 4: 91, 5: 58, 6: 41, 7: 32, 8: 27},
#   927: {1: 356, 2: 148, 3: 91, 4: 54, 5: 32, 6: 22, 7: 21, 8: 18},
#   928: {1: 454, 2: 182, 3: 121, 4: 86, 5: 55, 6: 40, 7: 35, 8: 28},
#   929: {1: 496, 2: 160, 3: 102, 4: 79, 5: 41, 6: 33, 7: 27, 8: 27},
#   930: {1: 453, 2: 222, 3: 144, 4: 103, 5: 67, 6: 47, 7: 24, 8: 24},
#   931: {1: 431, 2: 248, 3: 169, 4: 113, 5: 51, 6: 39, 7: 27, 8: 25},
#   932: {1: 573, 2: 276, 3: 161, 4: 97, 5: 54, 6: 38, 7: 35, 8: 30},
#   933: {1: 463, 2: 191, 3: 136, 4: 93, 5: 50, 6: 47, 7: 32, 8: 29},
#   934: {1: 397, 2: 121, 3: 71, 4: 54, 5: 29, 6: 16, 7: 14, 8: 11},
#   935: {1: 511, 2: 213, 3: 140, 4: 63, 5: 20, 6: 19, 7: 13, 8: 11},
#   936: {1: 475, 2: 166, 3: 81, 4: 45, 5: 33, 6: 17, 7: 13, 8: 8},
#   937: {1: 459, 2: 166, 3: 117, 4: 71, 5: 28, 6: 18, 7: 14, 8: 11},
#   938: {1: 432, 2: 183, 3: 143, 4: 75, 5: 34, 6: 20, 7: 18, 8: 16},
#   939: {1: 547, 2: 232, 3: 135, 4: 69, 5: 30, 6: 27, 7: 16, 8: 16},
#   940: {1: 467, 2: 271, 3: 144, 4: 111, 5: 74, 6: 37, 7: 29, 8: 24},
#   941: {1: 565, 2: 274, 3: 173, 4: 97, 5: 51, 6: 41, 7: 27, 8: 27},
#   942: {1: 501, 2: 263, 3: 167, 4: 97, 5: 52, 6: 23, 7: 20, 8: 15},
#   943: {1: 395, 2: 213, 3: 115, 4: 80, 5: 48, 6: 36, 7: 30, 8: 29},
#   944: {1: 396, 2: 129, 3: 84, 4: 57, 5: 32, 6: 15, 7: 14, 8: 14},
#   945: {1: 470, 2: 190, 3: 117, 4: 58, 5: 33, 6: 23, 7: 22, 8: 21},
#   946: {1: 511, 2: 286, 3: 179, 4: 102, 5: 50, 6: 33, 7: 26, 8: 23},
#   947: {1: 515, 2: 249, 3: 156, 4: 106, 5: 64, 6: 50, 7: 42, 8: 36},
#   948: {1: 501, 2: 246, 3: 125, 4: 65, 5: 33, 6: 25, 7: 18, 8: 17},
#   949: {1: 455, 2: 182, 3: 115, 4: 64, 5: 25, 6: 18, 7: 18, 8: 18},
#   950: {1: 461, 2: 168, 3: 110, 4: 62, 5: 34, 6: 22, 7: 16, 8: 15},
#   951: {1: 580, 2: 273, 3: 153, 4: 63, 5: 40, 6: 24, 7: 15, 8: 15},
#   952: {1: 557, 2: 224, 3: 139, 4: 96, 5: 46, 6: 36, 7: 32, 8: 26},
#   953: {1: 397, 2: 170, 3: 121, 4: 73, 5: 28, 6: 24, 7: 19, 8: 16},
#   954: {1: 469, 2: 209, 3: 131, 4: 71, 5: 46, 6: 27, 7: 22, 8: 22},
#   955: {1: 484, 2: 208, 3: 145, 4: 89, 5: 60, 6: 34, 7: 24, 8: 22},
#   956: {1: 616, 2: 325, 3: 145, 4: 92, 5: 49, 6: 33, 7: 28, 8: 26},
#   957: {1: 466, 2: 282, 3: 173, 4: 122, 5: 49, 6: 35, 7: 28, 8: 27},
#   958: {1: 500, 2: 126, 3: 82, 4: 46, 5: 22, 6: 13, 7: 11, 8: 10},
#   959: {1: 446, 2: 202, 3: 108, 4: 76, 5: 44, 6: 22, 7: 19, 8: 17},
#   960: {1: 450, 2: 194, 3: 96, 4: 62, 5: 34, 6: 12, 7: 10, 8: 9},
#   961: {1: 530, 2: 218, 3: 140, 4: 74, 5: 41, 6: 29, 7: 24, 8: 23},
#   962: {1: 407, 2: 129, 3: 71, 4: 50, 5: 27, 6: 19, 7: 16, 8: 14},
#   963: {1: 522, 2: 253, 3: 161, 4: 117, 5: 64, 6: 48, 7: 37, 8: 31},
#   964: {1: 518, 2: 244, 3: 140, 4: 102, 5: 64, 6: 46, 7: 27, 8: 25},
#   965: {1: 450, 2: 221, 3: 150, 4: 90, 5: 48, 6: 23, 7: 15, 8: 14},
#   966: {1: 593, 2: 282, 3: 184, 4: 125, 5: 46, 6: 23, 7: 17, 8: 15},
#   967: {1: 579, 2: 208, 3: 124, 4: 75, 5: 46, 6: 36, 7: 32, 8: 30},
#   968: {1: 464, 2: 174, 3: 98, 4: 66, 5: 38, 6: 26, 7: 19, 8: 17},
#   969: {1: 549, 2: 196, 3: 141, 4: 96, 5: 53, 6: 29, 7: 19, 8: 17},
#   970: {1: 523, 2: 236, 3: 136, 4: 106, 5: 64, 6: 49, 7: 42, 8: 35},
#   971: {1: 623, 2: 310, 3: 174, 4: 97, 5: 60, 6: 33, 7: 26, 8: 25},
#   972: {1: 499, 2: 237, 3: 124, 4: 89, 5: 50, 6: 33, 7: 29, 8: 28},
#   973: {1: 470, 2: 219, 3: 154, 4: 86, 5: 34, 6: 28, 7: 20, 8: 18},
#   974: {1: 476, 2: 260, 3: 166, 4: 118, 5: 65, 6: 38, 7: 37, 8: 37},
#   975: {1: 507, 2: 269, 3: 171, 4: 99, 5: 44, 6: 32, 7: 27, 8: 26},
#   976: {1: 464, 2: 146, 3: 80, 4: 48, 5: 30, 6: 24, 7: 22, 8: 18},
#   977: {1: 470, 2: 208, 3: 120, 4: 79, 5: 38, 6: 32, 7: 22, 8: 20},
#   978: {1: 576, 2: 262, 3: 159, 4: 96, 5: 50, 6: 39, 7: 29, 8: 28},
#   979: {1: 503, 2: 139, 3: 86, 4: 52, 5: 29, 6: 18, 7: 18, 8: 13},
#   980: {1: 469, 2: 113, 3: 73, 4: 45, 5: 19, 6: 12, 7: 9, 8: 7},
#   981: {1: 341, 2: 145, 3: 79, 4: 54, 5: 33, 6: 25, 7: 24, 8: 21},
#   982: {1: 484, 2: 172, 3: 85, 4: 55, 5: 33, 6: 20, 7: 11, 8: 10},
#   983: {1: 517, 2: 153, 3: 80, 4: 47, 5: 33, 6: 22, 7: 14, 8: 8},
#   984: {1: 469, 2: 248, 3: 150, 4: 99, 5: 52, 6: 24, 7: 18, 8: 16},
#   985: {1: 547, 2: 220, 3: 146, 4: 98, 5: 54, 6: 43, 7: 43, 8: 40},
#   986: {1: 480, 2: 137, 3: 87, 4: 51, 5: 26, 6: 17, 7: 11, 8: 10},
#   987: {1: 495, 2: 118, 3: 70, 4: 38, 5: 25, 6: 18, 7: 9, 8: 8},
#   988: {1: 485, 2: 234, 3: 158, 4: 110, 5: 47, 6: 31, 7: 25, 8: 21},
#   989: {1: 450, 2: 200, 3: 126, 4: 77, 5: 43, 6: 34, 7: 29, 8: 29},
#   990: {1: 558, 2: 249, 3: 135, 4: 61, 5: 25, 6: 18, 7: 15, 8: 15},
#   991: {1: 459, 2: 209, 3: 111, 4: 92, 5: 49, 6: 40, 7: 30, 8: 25},
#   992: {1: 484, 2: 144, 3: 99, 4: 55, 5: 29, 6: 26, 7: 19, 8: 14},
#   993: {1: 460, 2: 206, 3: 130, 4: 64, 5: 38, 6: 22, 7: 15, 8: 14},
#   994: {1: 535, 2: 266, 3: 165, 4: 115, 5: 84, 6: 76, 7: 68, 8: 64},
#   995: {1: 434, 2: 165, 3: 102, 4: 70, 5: 37, 6: 24, 7: 11, 8: 10},
#   996: {1: 530, 2: 173, 3: 98, 4: 58, 5: 29, 6: 24, 7: 23, 8: 23},
#   997: {1: 576, 2: 197, 3: 110, 4: 73, 5: 46, 6: 36, 7: 27, 8: 26},
#   998: {1: 492, 2: 244, 3: 167, 4: 118, 5: 53, 6: 31, 7: 28, 8: 26},
#   999: {1: 445, 2: 137, 3: 66, 4: 49, 5: 28, 6: 14, 7: 9, 8: 9},
#   1000: {1: 516, 2: 193, 3: 116, 4: 76, 5: 38, 6: 23, 7: 17, 8: 14},
#   ...},
#  [26,
#   12,
#   10,
#   43,
#   23,
#   16,
#   13,
#   14,
#   25,
#   11,
#   10,
#   15,
#   35,
#   19,
#   18,
#   25,
#   12,
#   22,
#   30,
#   15,
#   19,
#   16,
#   12,
#   16,
#   45,
#   16,
#   12,
#   11,
#   27,
#   23,
#   33,
#   38,
#   38,
#   23,
#   16,
#   29,
#   11,
#   31,
#   17,
#   20,
#   20,
#   36,
#   20,
#   28,
#   10,
#   16,
#   9,
#   35,
#   13,
#   10,
#   19,
#   30,
#   12,
#   20,
#   10,
#   13,
#   55,
#   14,
#   17,
#   20,
#   16,
#   27,
#   30,
#   15,
#   9,
#   32,
#   8,
#   23,
#   9,
#   22,
#   26,
#   14,
#   9,
#   12,
#   15,
#   22,
#   19,
#   33,
#   11,
#   15,
#   37,
#   32,
#   19,
#   9,
#   22,
#   16,
#   21,
#   21,
#   10,
#   10,
#   18,
#   18,
#   21,
#   6,
#   18,
#   14,
#   20,
#   30,
#   38,
#   30,
#   13,
#   10,
#   19,
#   13,
#   11,
#   18,
#   12,
#   24,
#   13,
#   32,
#   23,
#   16,
#   14,
#   10,
#   30,
#   22,
#   25,
#   15,
#   16,
#   30,
#   32,
#   19,
#   23,
#   27,
#   29,
#   13,
#   11,
#   19,
#   40,
#   18,
#   11,
#   23,
#   7,
#   16,
#   25,
#   19,
#   16,
#   7,
#   33,
#   11,
#   22,
#   11,
#   5,
#   17,
#   16,
#   67,
#   20,
#   25,
#   31,
#   9,
#   8,
#   29,
#   14,
#   14,
#   11,
#   21,
#   24,
#   21,
#   9,
#   24,
#   30,
#   26,
#   27,
#   7,
#   17,
#   17,
#   9,
#   12,
#   11,
#   23,
#   8,
#   49,
#   36,
#   18,
#   17,
#   12,
#   11,
#   25,
#   11,
#   16,
#   22,
#   8,
#   18,
#   12,
#   38,
#   32,
#   10,
#   18,
#   19,
#   13,
#   11,
#   28,
#   22,
#   34,
#   27,
#   7,
#   28,
#   14,
#   24,
#   16,
#   18,
#   14,
#   24,
#   9,
#   15,
#   9,
#   19,
#   25,
#   13,
#   24,
#   22,
#   27,
#   15,
#   14,
#   12,
#   20,
#   35,
#   14,
#   13,
#   28,
#   20,
#   15,
#   29,
#   21,
#   15,
#   11,
#   13,
#   23,
#   18,
#   17,
#   23,
#   30,
#   18,
#   7,
#   33,
#   26,
#   15,
#   27,
#   9,
#   17,
#   35,
#   22,
#   29,
#   11,
#   14,
#   7,
#   24,
#   21,
#   11,
#   33,
#   35,
#   7,
#   7,
#   26,
#   18,
#   17,
#   24,
#   19,
#   18,
#   11,
#   16,
#   18,
#   25,
#   30,
#   29,
#   12,
#   13,
#   18,
#   41,
#   7,
#   21,
#   27,
#   15,
#   11,
#   13,
#   17,
#   16,
#   42,
#   20,
#   31,
#   16,
#   17,
#   17,
#   24,
#   13,
#   34,
#   4,
#   9,
#   36,
#   14,
#   18,
#   16,
#   28,
#   17,
#   9,
#   23,
#   13,
#   13,
#   22,
#   12,
#   47,
#   11,
#   14,
#   23,
#   25,
#   30,
#   25,
#   19,
#   25,
#   17,
#   13,
#   26,
#   10,
#   15,
#   24,
#   25,
#   9,
#   16,
#   37,
#   28,
#   13,
#   18,
#   35,
#   19,
#   16,
#   8,
#   21,
#   9,
#   19,
#   24,
#   20,
#   52,
#   15,
#   19,
#   14,
#   23,
#   28,
#   19,
#   10,
#   14,
#   11,
#   32,
#   14,
#   12,
#   11,
#   19,
#   9,
#   20,
#   28,
#   25,
#   20,
#   35,
#   31,
#   15,
#   19,
#   18,
#   22,
#   23,
#   21,
#   17,
#   19,
#   26,
#   28,
#   28,
#   7,
#   17,
#   25,
#   33,
#   14,
#   23,
#   24,
#   17,
#   8,
#   38,
#   17,
#   17,
#   8,
#   6,
#   25,
#   13,
#   22,
#   17,
#   22,
#   14,
#   15,
#   10,
#   19,
#   38,
#   19,
#   25,
#   19,
#   14,
#   32,
#   22,
#   9,
#   13,
#   13,
#   15,
#   19,
#   22,
#   27,
#   14,
#   17,
#   15,
#   18,
#   27,
#   24,
#   20,
#   14,
#   16,
#   18,
#   22,
#   20,
#   16,
#   14,
#   17,
#   19,
#   15,
#   8,
#   22,
#   35,
#   20,
#   57,
#   23,
#   14,
#   23,
#   13,
#   34,
#   19,
#   17,
#   13,
#   26,
#   25,
#   14,
#   25,
#   22,
#   25,
#   13,
#   35,
#   16,
#   17,
#   17,
#   26,
#   10,
#   23,
#   13,
#   13,
#   30,
#   13,
#   17,
#   15,
#   29,
#   11,
#   8,
#   19,
#   18,
#   22,
#   19,
#   22,
#   18,
#   22,
#   13,
#   17,
#   17,
#   20,
#   26,
#   13,
#   23,
#   13,
#   19,
#   27,
#   12,
#   31,
#   15,
#   19,
#   12,
#   18,
#   21,
#   16,
#   28,
#   10,
#   50,
#   23,
#   12,
#   17,
#   14,
#   7,
#   27,
#   15,
#   26,
#   5,
#   25,
#   16,
#   13,
#   34,
#   18,
#   28,
#   15,
#   26,
#   8,
#   17,
#   15,
#   10,
#   5,
#   17,
#   4,
#   13,
#   34,
#   16,
#   27,
#   37,
#   14,
#   28,
#   11,
#   21,
#   23,
#   25,
#   15,
#   14,
#   20,
#   34,
#   19,
#   13,
#   19,
#   7,
#   22,
#   11,
#   11,
#   7,
#   22,
#   31,
#   14,
#   27,
#   10,
#   19,
#   13,
#   15,
#   17,
#   6,
#   14,
#   16,
#   59,
#   13,
#   15,
#   31,
#   13,
#   10,
#   20,
#   19,
#   33,
#   27,
#   31,
#   8,
#   20,
#   14,
#   25,
#   27,
#   14,
#   9,
#   13,
#   32,
#   30,
#   19,
#   27,
#   23,
#   33,
#   26,
#   20,
#   21,
#   36,
#   36,
#   17,
#   23,
#   15,
#   19,
#   26,
#   13,
#   32,
#   17,
#   21,
#   30,
#   41,
#   19,
#   29,
#   40,
#   22,
#   21,
#   24,
#   12,
#   9,
#   31,
#   35,
#   6,
#   12,
#   20,
#   22,
#   37,
#   31,
#   19,
#   26,
#   41,
#   18,
#   28,
#   22,
#   24,
#   39,
#   22,
#   6,
#   24,
#   20,
#   15,
#   32,
#   9,
#   17,
#   13,
#   28,
#   19,
#   29,
#   14,
#   17,
#   22,
#   19,
#   45,
#   7,
#   8,
#   23,
#   23,
#   17,
#   24,
#   18,
#   17,
#   17,
#   7,
#   25,
#   38,
#   23,
#   22,
#   16,
#   21,
#   17,
#   15,
#   42,
#   7,
#   13,
#   18,
#   17,
#   21,
#   28,
#   40,
#   25,
#   29,
#   20,
#   14,
#   21,
#   6,
#   23,
#   8,
#   11,
#   22,
#   11,
#   26,
#   25,
#   21,
#   16,
#   11,
#   14,
#   9,
#   7,
#   29,
#   22,
#   12,
#   13,
#   11,
#   22,
#   17,
#   27,
#   20,
#   22,
#   7,
#   22,
#   26,
#   19,
#   36,
#   12,
#   28,
#   11,
#   28,
#   17,
#   13,
#   14,
#   11,
#   13,
#   9,
#   19,
#   49,
#   21,
#   52,
#   24,
#   17,
#   29,
#   10,
#   16,
#   21,
#   13,
#   11,
#   22,
#   18,
#   31,
#   13,
#   20,
#   19,
#   24,
#   20,
#   38,
#   35,
#   13,
#   10,
#   24,
#   19,
#   15,
#   13,
#   33,
#   20,
#   9,
#   12,
#   13,
#   13,
#   11,
#   25,
#   18,
#   22,
#   11,
#   31,
#   17,
#   19,
#   9,
#   16,
#   15,
#   18,
#   17,
#   20,
#   39,
#   25,
#   22,
#   29,
#   23,
#   17,
#   10,
#   18,
#   9,
#   12,
#   23,
#   7,
#   19,
#   14,
#   25,
#   15,
#   28,
#   41,
#   24,
#   24,
#   26,
#   20,
#   12,
#   4,
#   15,
#   7,
#   30,
#   16,
#   26,
#   21,
#   14,
#   24,
#   8,
#   8,
#   32,
#   12,
#   8,
#   32,
#   25,
#   40,
#   19,
#   25,
#   15,
#   17,
#   7,
#   9,
#   16,
#   21,
#   8,
#   31,
#   17,
#   26,
#   28,
#   12,
#   18,
#   17,
#   23,
#   16,
#   10,
#   27,
#   4,
#   16,
#   12,
#   13,
#   6,
#   20,
#   28,
#   8,
#   15,
#   23,
#   25,
#   22,
#   24,
#   26,
#   25,
#   20,
#   15,
#   15,
#   11,
#   28,
#   11,
#   22,
#   15,
#   32,
#   35,
#   14,
#   14,
#   18,
#   26,
#   15,
#   19,
#   29,
#   9,
#   12,
#   29,
#   22,
#   26,
#   5,
#   5,
#   27,
#   19,
#   20,
#   8,
#   16,
#   24,
#   16,
#   13,
#   37,
#   17,
#   21,
#   16,
#   19,
#   17,
#   9,
#   21,
#   16,
#   15,
#   19,
#   18,
#   37,
#   21,
#   35,
#   10,
#   21,
#   23,
#   25,
#   22,
#   16,
#   15,
#   12,
#   7,
#   9,
#   20,
#   25,
#   16,
#   20,
#   24,
#   19,
#   8,
#   16,
#   19,
#   14,
#   28,
#   23,
#   29,
#   14,
#   25,
#   22,
#   23,
#   22,
#   26,
#   29,
#   18,
#   24,
#   17,
#   19,
#   20,
#   30,
#   13,
#   16,
#   18,
#   19,
#   36,
#   15,
#   15,
#   20,
#   19,
#   15,
#   20,
#   9,
#   19,
#   16,
#   12,
#   17,
#   31,
#   19,
#   19,
#   25,
#   25,
#   36,
#   13,
#   20,
#   18,
#   28,
#   27,
#   18,
#   28,
#   27,
#   24,
#   25,
#   30,
#   29,
#   11,
#   11,
#   8,
#   11,
#   16,
#   16,
#   24,
#   27,
#   15,
#   29,
#   14,
#   21,
#   23,
#   36,
#   17,
#   18,
#   15,
#   15,
#   26,
#   16,
#   22,
#   22,
#   26,
#   27,
#   10,
#   17,
#   9,
#   23,
#   14,
#   31,
#   25,
#   14,
#   15,
#   30,
#   17,
#   17,
#   35,
#   25,
#   28,
#   18,
#   37,
#   26,
#   18,
#   20,
#   28,
#   13,
#   7,
#   21,
#   10,
#   8,
#   16,
#   40,
#   10,
#   8,
#   21,
#   29,
#   15,
#   25,
#   14,
#   14,
#   64,
#   10,
#   23,
#   26,
#   26,
#   9,
#   14,
#   ...])

# %%
print "En promedio se espera que para la generación de 2015, salgan: %.0f" %pd.DataFrame(RESULTADO[1]).mean()
sns.distplot(pd.DataFrame(RESULTADO[1]),hist=True,kde=True,bins=25,color='blue')
# Out:
# En promedio se espera que para la generación de 2015, salgan: 20

# %%
f1 = Fitter(pd.DataFrame(RESULTADO[1]))
f1.fit()
# Out:
# Searching best parameters for distribution alpha (error 0.0204022290311)
# Searching best parameters for distribution anglit (error 0.0442443155136)
# Searching best parameters for distribution arcsine (error 0.0656979885813)
# Searching best parameters for distribution argus (error 0.053757354402)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/optimize/minpack.py:161: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# Searching best parameters for distribution beta (error 0.0203631848199)
# Searching best parameters for distribution betaprime (error 0.0203563026828)
# Searching best parameters for distribution bradford (error 0.0443048176844)
# Searching best parameters for distribution burr (error 0.0206756451963)
# Searching best parameters for distribution burr12 (error 0.0204470517257)
# Searching best parameters for distribution cauchy (error 0.0244722024957)
# Searching best parameters for distribution chi (error 0.0207961722461)
# Searching best parameters for distribution chi2 (error 0.0203631845989)
# Searching best parameters for distribution cosine (error 0.0388146374611)
# Searching best parameters for distribution dgamma (error 0.0202876370285)
# Searching best parameters for distribution dweibull (error 0.020609406509)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.25.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.75.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.8333333333333339.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.9583333333333339.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.875.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.9375.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.2083333333333339.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.8645833333333339.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.9722222222222232.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.9461805555555554.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.8738425925925934.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.8107638888888893.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.0154320987654319.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.9777199074074074.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.9548611111111107.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.9592013888888893.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.8709490740740744.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.8220486111111116.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.9388020833333339.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.9692322530864192.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.0169270833333321.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.0376478909465021.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.9126237782921809.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.9255776320301781.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.9328203589391855.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.9298294967421121.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.9704691429469587.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.987442963153482.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.018375628715134.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.976550592516384.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.9802097622313664.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.9818074488454496.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.0570990631191872.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.1207338463077257.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.994368554082202.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 4.982365016765737.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.0313084458987447.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.0560589444253914.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.0834722539755113.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.1351034998475846.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.058585910906622.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.184133886687329.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.2850183216481241.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.2588679330407775.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.3966008919322661.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.4918879312331939.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6702801469259985.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6423983072968138.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6685302919816909.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 6.0357875091548774.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.4727106185248129.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.5217290898500604.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6318299914487833.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.5408155306362481.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.56621122480139.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.7728369569259677.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.7077222276534547.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6508030504999507.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.829735544766554.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.632092304792681.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.5292800445531203.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.7119477288327563.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.7232616460464554.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.7688463166733417.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.7203948033267746.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6828088110261925.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.7612090734369872.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6784045562342094.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6777022800384813.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6862636422370505.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6417230269518468.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6621076817254981.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6683751091049794.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6719835345852836.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6554002061262763.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6785477832093569.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6633547767792169.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6671172216429646.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6829913445662381.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6777704288560535.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6769734212202998.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6732310062440376.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6859155905633347.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6806924911551011.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.682153522304624.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6902062370411581.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6803820837070766.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6845322138492698.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.691739511487663.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6811032406201978.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.687930487935918.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6890427798698529.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6912980628801435.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6800376611529195.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6906481281506913.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6956259466484873.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6983766028180547.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6846223965692033.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6882783817905791.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6880174613995838.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6864825442097988.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6884027209548389.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6833802577983921.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6888311605626161.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6922118320421546.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6865197554374411.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.687818296570347.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6863293547458014.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6882057091084128.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6876004937634494.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6876549444651738.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6865175517191791.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6879314286459239.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6893416327088993.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6886361633910347.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6888605896317417.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6879563557568158.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6881435894207701.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6881901791865026.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6874158123351268.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6877209000991034.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6879386495308708.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6879683905650618.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6879406691257088.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6879625160766736.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6879446161673215.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6875472777415848.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6880294538252727.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6882222593130987.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6878462399026022.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6879395374710882.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6879403862120537.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6879327704592981.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6879416547403157.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6880947566158264.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6879550778868566.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6880108598406682.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6878338439128635.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6880295284400857.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6880476424686606.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6879672002762049.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 5.6880634042976563.
#   RuntimeWarning)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2123: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value array(5.688010859840668).
#   RuntimeWarning)
# Searching best parameters for distribution erlang (error 0.0203631831536)
# Searching best parameters for distribution expon (error 0.0472673525334)
# Searching best parameters for distribution exponnorm (error 0.0206193592119)
# Searching best parameters for distribution exponpow (error 0.0249558491526)
# Searching best parameters for distribution exponweib (error 0.0203544393833)
# Searching best parameters for distribution f (error 0.0203564058846)
# Searching best parameters for distribution fatiguelife (error 0.0203542219062)
# Searching best parameters for distribution fisk (error 0.0206958977165)
# Searching best parameters for distribution foldcauchy (error 0.0235571748115)
# Searching best parameters for distribution foldnorm (error 0.0371254219917)
# Searching best parameters for distribution frechet_l (error 0.0203761566325)
# Searching best parameters for distribution frechet_r (error 0.19476533702)
# Searching best parameters for distribution gamma (error 0.020363185192)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:2587: RuntimeWarning: invalid value encountered in power
#   return 1.0/Cinv * x**(a-1.0) * (1.0-x)**(b-1.0) / (1.0+z*x)**c
# Searching best parameters for distribution gausshyper (error 0.0204487175725)
# Searching best parameters for distribution genexpon (error 0.0246069631437)
# Searching best parameters for distribution genextreme (error 0.0203761492201)
# Searching best parameters for distribution gengamma (error 0.0203567111552)
# Searching best parameters for distribution genhalflogistic (error 0.0339265022265)
# Searching best parameters for distribution genlogistic (error 0.0203994300786)
# Searching best parameters for distribution gennorm (error 0.0222244866308)
# Searching best parameters for distribution genpareto (error 0.040138556717)
# Searching best parameters for distribution gilbrat (error 0.0356759242703)
# Searching best parameters for distribution gompertz (error 0.139007120787)
# Searching best parameters for distribution gumbel_l (error 0.0293954848748)
# Searching best parameters for distribution gumbel_r (error 0.0204029540242)
# Searching best parameters for distribution halfcauchy (error 0.0438806725549)
# Searching best parameters for distribution halfgennorm (error 0.0693181737447)
# Searching best parameters for distribution halflogistic (error 0.0388593836663)
# Searching best parameters for distribution halfnorm (error 0.0370773786648)
# Searching best parameters for distribution hypsecant (error 0.0222035097721)
# Searching best parameters for distribution invgamma (error 0.0203745270025)
# Searching best parameters for distribution invgauss (error 0.0203545758257)
# Searching best parameters for distribution invweibull (error 0.0204029359349)
# Searching best parameters for distribution johnsonsb (error 0.0203541891138)
# Searching best parameters for distribution johnsonsu (error 0.0203610933896)
# Searching best parameters for distribution kappa3 (error 0.0310173869233)
# Searching best parameters for distribution kappa4 (error 0.0485915910672)
# Searching best parameters for distribution ksone (error nan)
# Searching best parameters for distribution kstwobign (error 0.0204406917356)
# Searching best parameters for distribution laplace (error 0.0247131145499)
# Searching best parameters for distribution levy (error 0.0437454297568)
# Searching best parameters for distribution levy_l (error 0.0609150746916)
# (<type 'exceptions.NotImplementedError'>, NotImplementedError(), <traceback object at 0x7f496aab1320>)
# SKIPPED levy_stable distribution (taking more than 10 seconds)
# Searching best parameters for distribution loggamma (error 0.0227802858019)
# Searching best parameters for distribution logistic (error 0.0220394752264)
# Searching best parameters for distribution loglaplace (error 0.0231518050047)
# Searching best parameters for distribution lognorm (error 0.0203610592467)
# Searching best parameters for distribution lomax (error 0.0474543154954)
# Searching best parameters for distribution maxwell (error 0.0208532539896)
# Searching best parameters for distribution mielke (error 0.0206760892072)
# Searching best parameters for distribution nakagami (error 0.0744834097281)
# Stop has been called
# SKIPPED ncf distribution (taking more than 10 seconds)
# Stop has been called
# SKIPPED nct distribution (taking more than 10 seconds)
# Searching best parameters for distribution ncx2 (error 0.0633965897123)
# Searching best parameters for distribution norm (error 0.0225522747647)
# Searching best parameters for distribution pareto (error 0.050111048209)
# Searching best parameters for distribution pearson3 (error 0.0203631861686)
# Searching best parameters for distribution powerlaw (error 0.0512166858402)
# Searching best parameters for distribution powerlognorm (error 0.0203600517862)
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:4313: RuntimeWarning: divide by zero encountered in power
#   return c*_norm_pdf(x) * (_norm_cdf(-x)**(c-1.0))
# /home/dbh/anaconda2/lib/python2.7/site-packages/scipy/stats/_continuous_distns.py:4313: RuntimeWarning: invalid value encountered in multiply
#   return c*_norm_pdf(x) * (_norm_cdf(-x)**(c-1.0))
# Searching best parameters for distribution powernorm (error nan)
# Searching best parameters for distribution rayleigh (error 0.0222442231209)
# Searching best parameters for distribution rdist (error 0.0225597982536)
# Searching best parameters for distribution recipinvgauss (error 0.0203540887654)
# Searching best parameters for distribution reciprocal (error 0.0703592937909)
# Searching best parameters for distribution rice (error 0.021602694972)
# (<type 'exceptions.TypeError'>, TypeError('unbound method fit() must be called with rv_continuous instance as first argument (got ndarray instance instead)',), <traceback object at 0x7f496ac178c0>)
# SKIPPED rv_continuous distribution (taking more than 10 seconds)
# (<type 'exceptions.TypeError'>, TypeError('unbound method fit() must be called with rv_histogram instance as first argument (got ndarray instance instead)',), <traceback object at 0x7f496aab13f8>)
# SKIPPED rv_histogram distribution (taking more than 10 seconds)
# Searching best parameters for distribution semicircular (error 0.048397232938)
# Searching best parameters for distribution skewnorm (error 0.0204214230966)
# Searching best parameters for distribution t (error 0.022043556986)
# Searching best parameters for distribution trapz (error 0.0672049613143)
# Searching best parameters for distribution triang (error 0.0321616866229)
# Searching best parameters for distribution truncexpon (error 0.0420448708874)
# Searching best parameters for distribution truncnorm (error 0.0703592937909)
# Stop has been called
# SKIPPED tukeylambda distribution (taking more than 10 seconds)
# Searching best parameters for distribution uniform (error 0.0505219599288)
# Searching best parameters for distribution vonmises (error 1.37758560918e+58)
# Searching best parameters for distribution vonmises_line (error 0.0221922569389)
# Searching best parameters for distribution wald (error 0.031851066522)
# Searching best parameters for distribution weibull_max (error 0.0203761566325)
# Searching best parameters for distribution weibull_min (error 0.19476533702)
# Searching best parameters for distribution wrapcauchy (error nan)

# %%
f1.summary(Nbest=10)
# Out:
#                sumsquare_error
# dgamma                0.020288
# recipinvgauss         0.020354
# johnsonsb             0.020354
# fatiguelife           0.020354
# exponweib             0.020354
# invgauss              0.020355
# betaprime             0.020356
# f                     0.020356
# gengamma              0.020357
# powerlognorm          0.020360

# %% [markdown]
# # Simulaciones

# %% [markdown]
# ### Aumento de matricula

# %%
def sim_ingreso_prop(n,gen):
    z=[]
    for i in range(0,n):
        z.append(int(np.random.normal(1000,100,1)))
    return z

# %%
def GENERACIONES_prop1(n):
    gen=dict()
    egre=[]
    for k in range(1,n+1):
        ingreso=sim_ingreso_prop(1,2015)[0]
        semestre=dict()
        semestre[1]=ingreso
        for i in range(1,8):
            if i==1:
                hij=info_1(meter_1(semestre[i]))
            elif i==2:
                hij=info_2(meter_1(semestre[i]))
            elif i==3:
                hij=info_3(meter_1(semestre[i]))
            elif i==4:
                hij=info_4(meter_1(semestre[i]))
            elif i==5:
                hij=info_5(meter_1(semestre[i]))
            elif i==6: 
                hij=info_6(meter_1(semestre[i]))
            elif i==7:
                hij=info_7(meter_1(semestre[i]))
            else:
                hij=info_8(meter_1(semestre[i]))

            if i==1:
                semestre[i+1]=hij[0][hij[0]['CALCULO DIFERENCIAL E INTEGRAL I']==1].count()[2]
            elif i==2:
                semestre[i+1]=hij[0][hij[0]['CALCULO DIFERENCIAL E INTEGRAL II']==1].count()[2]
            elif i==3:
                semestre[i+1]=hij[0][hij[0]['PROBABILIDAD I']==1].count()[2]
            elif i==4:
                semestre[i+1]=hij[0][hij[0]['ESTADISTICA I']==1].count()[2]
            elif i==5:
                semestre[i+1]=hij[0][hij[0]['PROBABILIDAD II']==1].count()[2]
            elif i==6:
                semestre[i+1]=hij[0][hij[0]['PROCESOS ESTOCASTICOS I']==1].count()[2]
            elif i==7:
                semestre[i+1]=hij[0][hij[0]['TEORIA DEL RIESGO I']==1].count()[2]
            else:
                semestre[i+1]=hij[0][hij[0]['ADMINISTRACION DE RIESGOS']==1].count()[2]
        gen[k]=semestre
        egre.append(semestre[8])
    return gen,egre

# %%
n=3
RESULTADO= GENERACIONES_prop1(n)

# %%
RESULTADO
# Out:
# ({1: {1: 999, 2: 503, 3: 270, 4: 184, 5: 117, 6: 103, 7: 84, 8: 81},
#   2: {1: 968, 2: 443, 3: 267, 4: 133, 5: 90, 6: 48, 7: 34, 8: 29},
#   3: {1: 801, 2: 347, 3: 215, 4: 110, 5: 63, 6: 39, 7: 31, 8: 28}},
#  [81, 29, 28])

# %% [markdown]
# ### Asesorias

# %%
probadetodo=proba_aproba('TEORIA DEL RIESGO I')
if probadetodo<.95:
    d=(probadetodo+.05)
else:
    d=(probadetodo)
d
#probadetodo
# Out:
# 0.94999999999999996

# %%
def aprobacion_grupo_prop():
    c=dict()
    for j in range(1,7):
        d=[]
        probadetodo=[]
        for i in a[j]['MATERIA'].tolist():
            if i=='CALCULO DIFERENCIAL E INTEGRAL I' or i=='CALCULO DIFERENCIAL E INTEGRAL II'or i=='PROBABILIDAD I'or i=='ESTADISTICA I' or i=='PROBABILIDAD II'or i=='PROCESOS ESTOCASTICOS I':
                probadetodo=proba_aproba(i)
                if probadetodo<.95:
                    d.append(probadetodo+.05)
                else:
                    d.append(probadetodo)
            else:
                d.append(proba_aproba(i))
        o=a[j]['MATERIA'].tolist()
        abcd=pd.DataFrame(d,columns=['proba_aproba'])
        ou=pd.DataFrame(o,columns=['MATERIA'])
        c[j]=pd.concat([ou,abcd],axis=1)
    return c

def aprobacion_grupo_ultimos_prop():
    c=dict()
    d=[]
    probadetodo=[]
    for i in a[7]['MATERIA'].tolist():
        if i=='OPTATIVA_1' or i=='OPTATIVA_2' or i=='OPTATIVA_3'or i=='OPTATIVA_4'or i=='OPTATIVA_5':
            gh=0
            d.append(proba_aproba_optativa())
        else:
            if i=='TEORIA DEL RIESGO I' or i=='ADMINISTRACION DE RIESGOS':
                probadetodo=proba_aproba(i)
                if probadetodo<.95:
                    d.append(probadetodo+.05)
                else:
                    d.append(probadetodo)
            else:
                d.append(proba_aproba(i))
    o=a[7]['MATERIA'].tolist()
    abcd=pd.DataFrame(d,columns=['proba_aproba'])
    ou=pd.DataFrame(o,columns=['MATERIA'])
    c[7]=pd.concat([ou,abcd],axis=1)
    return c

def aprobacion_grupo_ultimos2_prop():
    c=dict()
    d=[]
    probadetodo=[]
    for i in a[8]['MATERIA'].tolist():
        if i=='OPTATIVA_1' or i=='OPTATIVA_2' or i=='OPTATIVA_3'or i=='OPTATIVAS_4'or i=='OPTATIVAS_5':
            gh=0
            d.append(proba_aproba_optativa())
        else:
            if i=='TEORIA DEL RIESGO I' or i=='ADMINISTRACION DE RIESGOS':
                probadetodo=proba_aproba(i)
                if probadetodo<.95:
                    d.append(probadetodo+.05)
                else:
                    d.append(probadetodo)
            else:
                d.append(proba_aproba(i))
    o=a[8]['MATERIA'].tolist()
    abcd=pd.DataFrame(d,columns=['proba_aproba'])
    ou=pd.DataFrame(o,columns=['MATERIA'])
    c[8]=pd.concat([ou,abcd],axis=1)
    return c

# %%
def info_1_prop(meter_12):
    grupos=dict()
    grupos[0]=[]
    for i in range(1,7+1):
        grupos[i]=aprobacion_grupo_prop()[1]
        for k in grupos[i]['MATERIA'].tolist():
            if i==1:
                meter_12[''+k+'']=map(lambda x: 0, range(0,len(meter_12['id_alumno'].tolist())))
            pro=float(grupos[i][grupos[i]['MATERIA']==k]['proba_aproba'])
            for j in meter_12[meter_12['grupo']==i]['id_alumno'].tolist():
                meter_12[''+k+''][meter_12['id_alumno']==j]=np.random.choice([1,0],p=[pro,1-pro])
    return meter_12,grupos

def info_2_prop(meter_12):
    grupos=dict()
    grupos[0]=[]
    for i in range(1,7+1):
        grupos[i]=aprobacion_grupo_prop()[2]
        for k in grupos[i]['MATERIA'].tolist():
            if i==1:
                meter_12[''+k+'']=map(lambda x: 0, range(0,len(meter_12['id_alumno'].tolist())))
            pro=float(grupos[i][grupos[i]['MATERIA']==k]['proba_aproba'])
            for j in meter_12[meter_12['grupo']==i]['id_alumno'].tolist():
                meter_12[''+k+''][meter_12['id_alumno']==j]=np.random.choice([1,0],p=[pro,1-pro])
    return meter_12,grupos

def info_3_prop(meter_12):
    grupos=dict()
    grupos[0]=[]
    for i in range(1,7+1):
        grupos[i]=aprobacion_grupo_prop()[3]
        for k in grupos[i]['MATERIA'].tolist():
            if i==1:
                meter_12[''+k+'']=map(lambda x: 0, range(0,len(meter_12['id_alumno'].tolist())))
            pro=float(grupos[i][grupos[i]['MATERIA']==k]['proba_aproba'])
            for j in meter_12[meter_12['grupo']==i]['id_alumno'].tolist():
                meter_12[''+k+''][meter_12['id_alumno']==j]=np.random.choice([1,0],p=[pro,1-pro])
    return meter_12,grupos

def info_4_prop(meter_12):
    grupos=dict()
    grupos[0]=[]
    for i in range(1,7+1):
        grupos[i]=aprobacion_grupo_prop()[4]
        for k in grupos[i]['MATERIA'].tolist():
            if i==1:
                meter_12[''+k+'']=map(lambda x: 0, range(0,len(meter_12['id_alumno'].tolist())))
            pro=float(grupos[i][grupos[i]['MATERIA']==k]['proba_aproba'])
            for j in meter_12[meter_12['grupo']==i]['id_alumno'].tolist():
                meter_12[''+k+''][meter_12['id_alumno']==j]=np.random.choice([1,0],p=[pro,1-pro])
    return meter_12,grupos

def info_5_prop(meter_12):
    grupos=dict()
    grupos[0]=[]
    for i in range(1,7+1):
        grupos[i]=aprobacion_grupo()[5]
        for k in grupos[i]['MATERIA'].tolist():
            if i==1:
                meter_12[''+k+'']=map(lambda x: 0, range(0,len(meter_12['id_alumno'].tolist())))
            pro=float(grupos[i][grupos[i]['MATERIA']==k]['proba_aproba'])
            for j in meter_12[meter_12['grupo']==i]['id_alumno'].tolist():
                meter_12[''+k+''][meter_12['id_alumno']==j]=np.random.choice([1,0],p=[pro,1-pro])
    return meter_12,grupos

def info_6_prop(meter_12):
    grupos=dict()
    grupos[0]=[]
    for i in range(1,7+1):
        grupos[i]=aprobacion_grupo_prop()[6]
        for k in grupos[i]['MATERIA'].tolist():
            if i==1:
                meter_12[''+k+'']=map(lambda x: 0, range(0,len(meter_12['id_alumno'].tolist())))
            pro=float(grupos[i][grupos[i]['MATERIA']==k]['proba_aproba'])
            for j in meter_12[meter_12['grupo']==i]['id_alumno'].tolist():
                meter_12[''+k+''][meter_12['id_alumno']==j]=np.random.choice([1,0],p=[pro,1-pro])
    return meter_12,grupos

# %%
def info_7_prop(meter_12):
    grupos=dict()
    grupos[0]=[]
    for i in range(1,7+1):
        grupos[i]=aprobacion_grupo_ultimos_prop()[7]
        for k in grupos[i]['MATERIA'].tolist():
            if i==1:
                meter_12[''+k+'']=map(lambda x: 0, range(0,len(meter_12['id_alumno'].tolist())))
            pro=float(grupos[i][grupos[i]['MATERIA']==k]['proba_aproba'])
            for j in meter_12[meter_12['grupo']==i]['id_alumno'].tolist():
                meter_12[''+k+''][meter_12['id_alumno']==j]=np.random.choice([1,0],p=[pro,1-pro])
    return meter_12,grupos

def info_8_prop(meter_12):
    grupos=dict()
    grupos[0]=[]
    for i in range(1,7+1):
        grupos[i]=aprobacion_grupo_ultimos2_prop()[8]
        for k in grupos[i]['MATERIA'].tolist():
            if i==1:
                meter_12[''+k+'']=map(lambda x: 0, range(0,len(meter_12['id_alumno'].tolist())))
            pro=float(grupos[i][grupos[i]['MATERIA']==k]['proba_aproba'])
            for j in meter_12[meter_12['grupo']==i]['id_alumno'].tolist():
                meter_12[''+k+''][meter_12['id_alumno']==j]=np.random.choice([1,0],p=[pro,1-pro])
    return meter_12,grupos

# %%
def GENERACIONES_prop2(n):
    gen=dict()
    egre=[]
    for k in range(1,n+1):
        ingreso=sim_ingreso(1,2015)[0]
        semestre=dict()
        semestre[1]=ingreso
        for i in range(1,8):
            if i==1:
                hij=info_1_prop(meter_1(semestre[i]))
            elif i==2:
                hij=info_2_prop(meter_1(semestre[i]))
            elif i==3:
                hij=info_3_prop(meter_1(semestre[i]))
            elif i==4:
                hij=info_4_prop(meter_1(semestre[i]))
            elif i==5:
                hij=info_5_prop(meter_1(semestre[i]))
            elif i==6: 
                hij=info_6_prop(meter_1(semestre[i]))
            elif i==7:
                hij=info_7_prop(meter_1(semestre[i]))
            else:
                hij=info_8_prop(meter_1(semestre[i]))

            if i==1:
                semestre[i+1]=hij[0][hij[0]['CALCULO DIFERENCIAL E INTEGRAL I']==1].count()[2]
            elif i==2:
                semestre[i+1]=hij[0][hij[0]['CALCULO DIFERENCIAL E INTEGRAL II']==1].count()[2]
            elif i==3:
                semestre[i+1]=hij[0][hij[0]['PROBABILIDAD I']==1].count()[2]
            elif i==4:
                semestre[i+1]=hij[0][hij[0]['ESTADISTICA I']==1].count()[2]
            elif i==5:
                semestre[i+1]=hij[0][hij[0]['PROBABILIDAD II']==1].count()[2]
            elif i==6:
                semestre[i+1]=hij[0][hij[0]['PROCESOS ESTOCASTICOS I']==1].count()[2]
            elif i==7:
                semestre[i+1]=hij[0][hij[0]['TEORIA DEL RIESGO I']==1].count()[2]
            else:
                semestre[i+1]=hij[0][hij[0]['ADMINISTRACION DE RIESGOS']==1].count()[2]
        gen[k]=semestre
        egre.append(semestre[8])
    return gen,egre

# %%
n=1
RESULTADO=GENERACIONES_prop2(n)

# %%
RESULTADO
# Out:
# ({1: {1: 564, 2: 255, 3: 165, 4: 87, 5: 53, 6: 46, 7: 31, 8: 29}}, [29])

# %% [markdown]
# ### Nueva seriación

# %%
def GENERACIONES_prop3(n):
    gen=dict()
    egre=[]
    for k in range(1,n+1):
        ingreso=sim_ingreso(1,2015)[0]
        semestre=dict()
        semestre[1]=ingreso
        for i in range(1,8):
            if i==1:
                hij=info_1(meter_1(semestre[i]))
            elif i==2:
                hij=info_2(meter_1(semestre[i]))
            elif i==3:
                hij=info_3(meter_1(semestre[i]))
            elif i==4:
                hij=info_4(meter_1(semestre[i]))
            elif i==5:
                hij=info_5(meter_1(semestre[i]))
            elif i==6: 
                hij=info_6(meter_1(semestre[i]))
            elif i==7:
                hij=info_7(meter_1(semestre[i]))
            else:
                hij=info_8(meter_1(semestre[i]))

            if i==1:
                semestre[i+1]=hij[0][hij[0]['ALGORITMOS Y PROGRAMACION']==1].count()[2]
            elif i==2:
                semestre[i+1]=hij[0][hij[0]['BASES DE DATOS']==1].count()[2]
            elif i==3:
                semestre[i+1]=hij[0][hij[0]['PROBABILIDAD I']==1].count()[2]
            elif i==4:
                semestre[i+1]=hij[0][hij[0]['ESTADISTICA I']==1].count()[2]
            elif i==5:
                semestre[i+1]=hij[0][hij[0]['PROBABILIDAD II']==1].count()[2]
            elif i==6:
                semestre[i+1]=hij[0][hij[0]['PROCESOS ESTOCASTICOS I']==1].count()[2]
            elif i==7:
                semestre[i+1]=hij[0][hij[0]['TEORIA DEL RIESGO I']==1].count()[2]
            else:
                semestre[i+1]=hij[0][hij[0]['ADMINISTRACION DE RIESGOS']==1].count()[2]
        gen[k]=semestre
        egre.append(semestre[8])
    return gen,egre

# %%
n=1
RESULTADO=GENERACIONES_prop3(n)

# %%
RESULTADO
# Out:
# ({1: {1: 461, 2: 371, 3: 288, 4: 171, 5: 68, 6: 39, 7: 32, 8: 30}}, [30])
